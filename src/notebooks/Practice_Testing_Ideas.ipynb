# %% [markdown]
# ## Saving cleaned df using Pickle

# %%
# import pickle
# fichero = open("C:/Users/Christiandda/Desktop/dataset/"+"anime.pkl","wb")
# pickle.dump(df_copy,fichero)
# fichero.close()

# %% [markdown]
# ## Opening cleaned df using Pickle

# %%
# fichero = open("C:/Users/Christiandda/Desktop/dataset/"+"anime.pkl","rb")
# df1 = pickle.load(fichero)
# fichero.close()
# Out:
# ---------------------------------------------------------------------------
#
# EOFError                                  Traceback (most recent call last)
#
# c:\Users\Christiandda\Documents\GitHub\EDA_ANIME\src\EDA_Anime.ipynb Celda 72 in <cell line: 2>()
#
#       <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA_ANIME/src/EDA_Anime.ipynb#Y431sZmlsZQ%3D%3D?line=0'>1</a> fichero = open("C:/Users/Christiandda/Desktop/dataset/"+"anime.pkl","rb")
#
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA_ANIME/src/EDA_Anime.ipynb#Y431sZmlsZQ%3D%3D?line=1'>2</a> df1 = pickle.load(fichero)
#
#       <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA_ANIME/src/EDA_Anime.ipynb#Y431sZmlsZQ%3D%3D?line=2'>3</a> fichero.close()
#
#
#
# EOFError: Ran out of input

# %% [markdown]
# ## Plotting Ideas

# %% [markdown]
# Ideas:
# Unidimensional
# - For Score a sns.displot and sns.boxplot
# - For Episodes a describe and sns.boxplot
# - Fro duration: convert to number, then  sns.displot and sns.boxplot
# - Genres: Top 10. sns.barplot
# - Producers: Top 10. sns.barplot
# - Licensors: Top 10. sns.barplot
# - Studios: Top 10. sns.barplot
# - Rating: .value_counts() and sns.countplot o treemap
# - Released:  Top 10.  sns.barplot. Tree map with types?
# - Season:  sns.barplot??
#
# Bidimensional
# - Score v Episodes corr. scatterplot?
# - Score v Duration corr. scatterplot?
# - Genres (all) v Score boxplot?
# - Genre (top10) boxplot top 10
# - BOXPLOT OF TOP10 PRODUCERS v Score
# - Producers v Score
# - Type v Score boxplot
# - BOXPLOT OF TOP10 Studio v Score
# - Studio v Score

# %% [markdown]
# - Barplot --> Type vs Episodes
# - Barplot --> Type vs Rating
# - Barplot --> top Producer by year (producer or publisher or whatever)
# - Barplot --> Top 5 producers by year (producer or publisher or whatever)
# - Countplot --> Genre
# - Countplot --> Audience
# - Countplot --> Type
# - Heatmap --> Rating, Genre and Type
# - Heatmap --> occurrences of Genre and Type
# - Histogram --> Rating
# - Pieplot --> Genre
# - Pieplot --> Type
# - Scatter --> Rating vs Episodes
# - Scatter --> Rating vs Type
# - boxplot --> episodes and type
# - boxplot --> members and type
# - violinplot --> episodes and type
# - violinplot --> members and type

# %%
def pieplot(data, colname):
    # Create an axis object
    fig, ax = plt.subplots(1, 1, figsize = (15, 8))
    
    # Get the data in the right format
    labels = list(data.keys())
    sizes  = list(data.values())
    
    # Plot the pie chart
    ax.pie(sizes, labels = labels, shadow = False, startangle = 0, autopct = "%1.2f%%")
    ax.axis('equal')
    ax.set_title(f"Pie chart for {colname} feature.")
    
    # Save the plot to an image
    # Show graphic
    plt.show()
    plt.close()

# %%
from collections import Counter
typedata = Counter(anime_copy["Type"])
all_genres = []
for item in anime_copy["Genre"]:
    item = item.strip().split(',')
    all_genres.extend(item)
genredata = Counter(all_genres)

all_themes = []
for item in anime_copy["Theme"]:
    item = item.strip().split(',')
    all_themes.extend(item)
themedata = Counter(all_themes)

pieplot(typedata, "Type")

pieplot(genredata, "Genre")

pieplot(themedata, "Theme")

# %%
# Process the genre column to split on comma and append resulting
# genres all to a single list
def annotate(self, ax, title, xax, yax, fs = 16):
        ax.set_title(title, fontsize = fs)
        ax.set_xlabel(xax, fontsize = fs - 2)
        ax.set_ylabel(yax, fontsize = fs - 2)

all_Producers = []
for item in anime_copy["Studios"]:
    item = item.strip()
    all_Producers.extend(item.split(','))

# Count the number of items in the genre and create a dataframe
c = Counter(all_Producers)

# make a list from the keys view
bars = list(c.keys()) 
x_pos = np.arange(len(bars))

# make a list from the values
height = list(c.values())  

# Create bars
plt.bar(x_pos, height)

# Create names on the x-axis
plt.xticks(x_pos, bars, color='orange',rotation=90)
plt.yticks(color='orange')

# Show graphic
plt.show()

# %%
# Process the genre column to split on comma and append resulting
# genres all to a single list
def annotate(self, ax, title, xax, yax, fs = 16):
        ax.set_title(title, fontsize = fs)
        ax.set_xlabel(xax, fontsize = fs - 2)
        ax.set_ylabel(yax, fontsize = fs - 2)

all_Producers = []
for item in anime_copy["Theme"]:
    item = item.strip()
    all_Producers.extend(item.split(','))

# Count the number of items in the genre and create a dataframe
c = Counter(all_Producers)

# make a list from the keys view
bars = list(c.keys()) 
x_pos = np.arange(len(bars))

# make a list from the values
height = list(c.values())  

# Create bars
plt.bar(x_pos, height)

# Create names on the x-axis
plt.xticks(x_pos, bars, color='orange',rotation=90)
plt.yticks(color='orange')

# Show graphic
plt.show()

# %%
# Process the genre column to split on comma and append resulting
# genres all to a single list
def annotate(self, ax, title, xax, yax, fs = 16):
        ax.set_title(title, fontsize = fs)
        ax.set_xlabel(xax, fontsize = fs - 2)
        ax.set_ylabel(yax, fontsize = fs - 2)

all_Producers = []
for item in anime_copy["Producers"]:
    item = item.strip()
    all_Producers.extend(item.split(','))

# Count the number of items in the genre and create a dataframe
c = Counter(all_Producers)

# make a list from the keys view
bars = list(c.keys()) 
x_pos = np.arange(len(bars))

# make a list from the values
height = list(c.values())  

# Create bars
plt.bar(x_pos, height)

# Create names on the x-axis
plt.xticks(x_pos, bars, color='orange',rotation=90)
plt.yticks(color='orange')

# Show graphic
plt.show()

# %%
# Process the genre column to split on comma and append resulting
# genres all to a single list
def annotate(self, ax, title, xax, yax, fs = 16):
        ax.set_title(title, fontsize = fs)
        ax.set_xlabel(xax, fontsize = fs - 2)
        ax.set_ylabel(yax, fontsize = fs - 2)

all_genres = []
for item in anime_copy["Genre"]:
    item = item.strip()
    all_genres.extend(item.split(','))

# Count the number of items in the genre and create a dataframe
c = Counter(all_genres)
# make a list from the keys view
bars = list(c.keys()) 
x_pos = np.arange(len(bars))

# make a list from the values
height = list(c.values())  

# Create bars
plt.bar(x_pos, height)

# Create names on the x-axis
plt.xticks(x_pos, bars, color='orange',rotation=90)
plt.yticks(color='orange')

# Show graphic
plt.show()

# %%
# Pieplot of a column. in the def we write the column data and the name we wan to give to the chart
utils.pieplot(df_copy["Type"],"Type")

# %%
utils.simple_barplot(df_copy["Source"],"Source")

# %%
def box(df,cat):
    plt.figure(figsize=(6,6))
    sns.boxplot(data = df , y = cat)

# %%
utils.box(df_copy,'N_Episodes') # Hacer una escala logaricmica  numpy loc de n_pisodios+1

# %%
# Fro duration: convert to number, then  sns.displot and sns.boxplot

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")

sns.histplot(data=df_copy, x="Released", bins=50)
plt.show()

# %%
# For Score a sns.displot and sns.boxplo
sns.displot(data = df_copy , x = 'Released' , kde = True) #anderson darling

# %%
# For Score a sns.displot and sns.boxplot
utils.simple_barplot(df_copy["Rating"],"Rating")

# %%
# For Score a sns.displot and sns.boxplo
sns.displot(data = df_copy , x = 'Score' , kde = True) #anderson darling

# %%
utils.box(df_copy,'Rank')

# %%
utils.box(df_copy,'Score')

# %%
df_copy["Score"].describe()
# Out:
# count    14867.000000
# mean         6.421725
# std          0.911462
# min          1.850000
# 25%          5.790000
# 50%          6.430000
# 75%          7.080000
# max          9.120000
# Name: Score, dtype: float64

# %%
df_copy["Score"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 14867 entries, 0 to 25811
# Series name: Score
# Non-Null Count  Dtype
# --------------  -----
# 14867 non-null  float64
# dtypes: float64(1)
# memory usage: 748.3 KB

# %%
# Get count of values greater than 20 in the column 'C' 
count = df_copy["Score"][df_copy["Score"] > 5].count()
count
# Out:
# 14018

# %%
df_copy.sample(5)
# Out:
#         Type    Source  N_Episodes       Duration           Status  \
# 3435     OVA  Original           1         23 min  Finished Airing
# 15812  Music     Music           1          4 min  Finished Airing
# 1402     OVA      Game           3  28 min per ep  Finished Airing
# 596       TV     Manga          13  24 min per ep  Finished Airing
# 23345    ONA  Original           1          5 min  Finished Airing
#
#                                Rating  Score  Scored_by  Rank          Genre  \
# 3435                      Rx - Hentai   5.16        601     0         Hentai
# 15812       PG-13 - Teens 13 or older   6.34       1246  7391        Unknown
# 1402        PG-13 - Teens 13 or older   6.60       1665  5917         Sci-Fi
# 596    R - 17+ (violence & profanity)   7.05      29090  3778  Drama,Romance
# 23345                    G - All Ages   6.15        291  8416        Unknown
#
#                Theme  Released       Studios  \
# 3435         Unknown      2007      Blue Cat
# 15812          Music      2016       Unknown
# 1402     Mecha,Space      2005  Brain's Base
# 596    Psychological      2004      A.C.G.T.
# 23345      Workplace      2022       Sunrise
#
#                                                Producers
# 3435                                              Animac
# 15812                           Sony Music Entertainment
# 1402                                       Bandai Visual
# 596    Geneon Universal Entertainment,TV Asahi,Rondo ...
# 23345                                            Unknown

# %%
# Genres: Top 10. sns.barplot
utils.complex_barplot(df_copy["Genre"],"Genre")

# %%
utils.complex_barplot(df_copy["Theme"],"Theme")

# %%
# Fro duration: convert to number, then  sns.displot and sns.boxplot

# %%
# Genres: Top 10. sns.barplot
utils.complex_barplot_top10(df_copy["Genre"])

# %%
# Producers: Top 10. sns.barplot
utils.complex_barplot_top10(df_copy["Producers"])

# %%
# Studios: Top 10. sns.barplot
utils.complex_barplot_top10(df_copy["Studios"])

# %%
# Rating: .value_counts() and sns.countplot o treemap
df_copy['Rating'].value_counts()
# Out:
# PG-13 - Teens 13 or older         6598
# G - All Ages                      3574
# Rx - Hentai                       1431
# R - 17+ (violence & profanity)    1225
# PG - Children                      975
# R+ - Mild Nudity                   970
# Unknown                             94
# Name: Rating, dtype: int64

# %%
utils.simple_barplot(df_copy["Rating"],"Rating")

# %%
# Released:  Top 10.  sns.barplot. Tree map with types?
utils.barplot_top10(df_copy["Released"])

# %%
import d3treeR

d3tree2( p ,  rootname = "General" )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Christiandda\Documents\GitHub\EDA\src\EDA_Anime.ipynb Celda 58 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA/src/EDA_Anime.ipynb#Y111sZmlsZQ%3D%3D?line=0'>1</a> import d3treeR
#       <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA/src/EDA_Anime.ipynb#Y111sZmlsZQ%3D%3D?line=2'>3</a> d3tree2( p ,  rootname = "General" )
#
# ModuleNotFoundError: No module named 'd3treeR'

# %%
utils.complex_barplot(df_copy["Genre"],"Genre")

# %%
# Season:  sns.barplot
utils.simple_barplot(df_copy["Released"],"Released")  ## -----> change it to histogram???  or barplot since 2000??

# %% [markdown]
# # Tries

# %%
# Collects for each feature the most frequent entry
most_frequent_entry = df_copy.mode()

# Checks for each entry if it contains the most frequent entry
df_freq = df_copy.eq(most_frequent_entry.values, axis=1)

# Computes the mean of the 'is_most_frequent' occurrence
df_freq = df_freq.mean().sort_values(ascending=False)

# Show the 5 top features with the highest ratio of singular value content
display(df_freq.head())

# Visualize the 'df_freq' table
df_freq.plot.bar(figsize=(15, 4));
# Out:
# Producers     0.538395
# Theme         0.460817
# N_Episodes    0.447459
# Studios       0.434101
# Source        0.370048
# dtype: float64

# %% [markdown]
# Feature relationships

# %%
# Computes feature correlation
df_corr = df_copy.corr(method="pearson")

# %%
# Create labels for the correlation matrix
labels = np.where(np.abs(df_corr)>0.75, "S",
                  np.where(np.abs(df_corr)>0.5, "M",
                           np.where(np.abs(df_corr)>0.25, "W", "")))

# Plot correlation matrix
plt.figure(figsize=(15, 15))
sns.heatmap(df_corr, mask=np.eye(len(df_corr)), square=True,
            center=0, annot=labels, fmt='', linewidths=.5,
            cmap="vlag", cbar_kws={"shrink": 0.8});

# %%
#  Creates a mask to remove the diagonal and the upper triangle.
lower_triangle_mask = np.tril(np.ones(df_corr.shape), k=-1).astype("bool")

#  Stack all correlations, after applying the mask
df_corr_stacked = df_corr.where(lower_triangle_mask).stack().sort_values()

#  Showing the lowest and highest correlations in the correlation matrix
display(df_corr_stacked)
# Out:
# Rank       Score        -0.484039
# Released   Rank         -0.085893
#            N_Episodes   -0.019330
# Rank       Scored_by    -0.011985
# Scored_by  N_Episodes    0.047300
# Rank       N_Episodes    0.049789
# Released   Scored_by     0.057732
# Score      N_Episodes    0.069993
# Scored_by  Score         0.141265
# Released   Score         0.220831
# dtype: float64

# %%
# Creates mask to identify numerical features with more or less than 25 unique features
cols_continuous = df_copy.select_dtypes(include="number").nunique() >= 25
# Create a new dataframe which only contains the continuous features
df_continuous = df_copy[cols_continuous[cols_continuous].index]
df_continuous.shape
import seaborn as sns

sns.pairplot(df_continuous, height=1.5, plot_kws={"s": 2, "alpha": 0.2});

# %%
# Plots the histogram for each numerical feature in a separate subplot
df_copy.hist(bins=25, figsize=(15, 15), layout=(-1, 5), edgecolor="black")
plt.tight_layout()

# %%
# Create figure object with 3 subplots
fig, axes = plt.subplots(ncols=1, nrows=3, figsize=(12, 8))

# Identify non-numerical features
df_non_numerical = df_copy.select_dtypes(exclude=["number", "datetime"])

# Loop through features and put each subplot on a matplotlib axis object
for col, ax in zip(df_non_numerical.columns, axes.ravel()):

    # Selects one single feature and counts number of occurrences per unique value
    df_non_numerical[col].value_counts().plot(

        # Plots this information in a figure with log-scaled y-axis
        logy=True, title=col, lw=0, marker=".", ax=ax)
    
plt.tight_layout();

# %%
df_copy.isna().mean().sort_values().plot(
    kind="bar", figsize=(15, 4),
    title="Percentage of missing values per feature",
    ylabel="Ratio of missing values per feature")

# %%
# For each numerical feature compute number of unique entries
unique_values = df_copy.select_dtypes(include="number").nunique().sort_values()

# Plot information with y-axis in log-scale
unique_values.plot.bar(logy=True, figsize=(15, 4), title="Unique values per feature");

# %%
# Computes feature correlation
df_corr = df_copy.corr(method="pearson")
df_corr
# Out:
#             N_Episodes     Score  Scored_by      Rank  Released  Finished
# N_Episodes    1.000000 -0.081739   0.020651  0.058097 -0.111920  0.226556
# Score        -0.081739  1.000000   0.236962 -0.551571  0.340307  0.128264
# Scored_by     0.020651  0.236962   1.000000 -0.193864  0.060391  0.203213
# Rank          0.058097 -0.551571  -0.193864  1.000000  0.137142 -0.042624
# Released     -0.111920  0.340307   0.060391  0.137142  1.000000  0.046490
# Finished      0.226556  0.128264   0.203213 -0.042624  0.046490  1.000000

# %%
# Plots the histogram for each numerical feature in a separate subplot
df_copy.hist(bins=25, figsize=(15, 25), layout=(-1, 5), edgecolor="black")
plt.tight_layout();

# %% [markdown]
# Ideas:
# Unidimensional
# - For Score a sns.displot and sns.boxplot----------------------------------------DONE
# - For Episodes a describe and sns.boxplot----------------------------------------DONE
# - Fro duration: convert to number, then  sns.displot and sns.boxplot
# - Genres: Top 10. sns.barplot----------------------------------------------------DONE
# - Producers: Top 10. sns.barplot-------------------------------------------------DONE
# - Licensors: Top 10. sns.barplot-------------------------------------------------DONE
# - Studios: Top 10. sns.barplot---------------------------------------------------DONE
# - Rating: .value_counts() and sns.countplot o treemap
# - Released:  Top 10.  sns.barplot. Tree map with types?
# - Season:  sns.barplot-----------------------------------------------------------DONE
#
# Bidimensional
# - Score v Episodes corr. scatterplot?
# - Score v Duration corr. scatterplot?
# - Genres (all) v Score boxplot?
# - Genre (top10) boxplot top 10
# - BOXPLOT OF TOP10 PRODUCERS v Score
# - Producers v Score
# - Type v Score boxplot
# - BOXPLOT OF TOP10 Studio v Score
# - Studio vs Score

# %%
# Collects for each feature the most frequent entry
most_frequent_entry = df_copy.mode()
most_frequent_entry
# Out:
#                                                Cover English_Title  \
# 0  https://cdn.myanimelist.net/img/sp/icon/apple-...   Castlevania
# 1                                                NaN           NaN
#
#   Japanses_Title Type    Source Audience  N_Episodes       Duration  \
# 0        おしりたんてい   TV  Original     Kids         1.0  24 min per ep
# 1    僕のヒーローアカデミア  NaN       NaN      NaN         NaN            NaN
#
#             Status                     Rating  Score  Scored_by  Rank  Season  \
# 0  Finished Airing  PG-13 - Teens 13 or older    0.0        0.0   0.0  spring
# 1              NaN                        NaN    NaN        NaN   NaN     NaN
#
#     Genre  Theme  Released  Finished         Studios Producers
# 0  Comedy  Music       0.0       0.0  Toei Animation       NHK
# 1     NaN    NaN       NaN       NaN             NaN       NaN

# %%
# Computes the mean of the 'is_most_frequent' occurrence
df_freq = df_copy.mean().sort_values(ascending=False)
df_freq
# Out:
# C:\Users\Christiandda\AppData\Local\Temp\ipykernel_17284\2198003371.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_freq = df_copy.mean().sort_values(ascending=False)
# Scored_by     17086.534349
# Rank           8905.003327
# Released       1840.505029
# Finished        676.467585
# N_Episodes       15.678632
# Score             3.693014
# dtype: float64

# %%
# Visualize the 'df_freq' table
df_freq.plot.bar(figsize=(15, 4));

# %%
Genre = df_copy['Genre'].str.split(',').explode().value_counts()
Genre
# Out:
# Comedy           4938
# Action           3780
# Fantasy          3046
# Adventure        2584
# Sci-Fi           2381
# Drama            2202
# Romance          1808
# Unknown          1533
# Hentai           1441
# Supernatural     1335
# Slice of Life    1307
# Ecchi             764
# Mystery           713
# Sports            532
# Horror            437
# Avant Garde       422
# Suspense          164
# Award Winning     157
# Boys Love         153
# Girls Love        101
# Gourmet            96
# Erotica            36
# Name: Genre, dtype: int64

# %%
# Checking the lenght of a column 

piedata = Counter(df_copy["Status"])
bars  = list(piedata.values())
length =len(bars)

print(length)
# Out:
# 2

# %%
df_copy["Genre"].value_counts()
# Out:
# Unknown                                       1533
# Comedy                                        1161
# Hentai                                        1146
# Fantasy                                        410
# Action,Sci-Fi                                  376
#                                               ...
# Avant Garde,Fantasy,Romance                      1
# Action,Comedy,Romance,Supernatural,Hentai        1
# Drama,Fantasy,Mystery,Romance,Supernatural       1
# Adventure,Comedy,Romance,Sports                  1
# Comedy,Romance,Sci-Fi,Supernatural               1
# Name: Genre, Length: 953, dtype: int64

# %%
df_copy["Genre"].unique()
# Out:
# array(['Action,Sci-Fi', 'Action,Adventure,Comedy,Drama,Sci-Fi',
#        'Action,Drama,Mystery,Supernatural',
#        'Adventure,Fantasy,Supernatural', 'Sports',
#        'Comedy,Drama,Romance,Slice of Life',
#        'Comedy,Slice of Life,Sports', 'Action,Drama',
#        'Drama,Mystery,Suspense', 'Action,Adventure,Fantasy',
#        'Action,Sports', 'Comedy,Romance',
#        'Action,Adventure,Comedy,Sci-Fi,Ecchi', 'Action,Drama,Sci-Fi',
#        'Action,Supernatural', 'Comedy,Gourmet',
#        'Action,Avant Garde,Award Winning,Drama,Sci-Fi,Suspense',
#        'Drama,Sci-Fi', 'Avant Garde,Drama,Sci-Fi',
#        'Action,Adventure,Drama,Fantasy,Horror,Supernatural',
#        'Action,Mystery,Sci-Fi,Suspense', 'Action,Drama,Romance',
#        'Action,Adventure,Comedy,Romance', 'Drama',
#        'Action,Adventure,Horror,Sci-Fi,Supernatural',
#        'Adventure,Fantasy,Mystery,Sci-Fi', 'Comedy,Romance,Supernatural',
#        'Action,Drama,Romance,Supernatural', 'Comedy,Drama,Sci-Fi,Sports',
#        'Comedy,Drama,Romance', 'Action,Adventure,Fantasy,Horror,Sci-Fi',
#        'Adventure,Fantasy,Sci-Fi', 'Comedy,Drama,Slice of Life',
#        'Adventure,Drama,Horror,Romance,Sci-Fi',
#        'Comedy,Drama,Romance,Sci-Fi,Ecchi', 'Action,Romance,Supernatural',
#        'Action,Comedy,Fantasy,Romance', 'Drama,Romance',
#        'Comedy,Romance,Sci-Fi,Ecchi', 'Action,Comedy,Drama',
#        'Comedy,Slice of Life',
#        'Action,Adventure,Fantasy,Romance,Supernatural',
#        'Adventure,Comedy,Sci-Fi', 'Action,Fantasy,Sci-Fi',
#        'Action,Comedy,Sci-Fi', 'Action,Comedy', 'Action', 'Comedy',
#        'Comedy,Drama,Fantasy,Romance,Ecchi',
#        'Adventure,Drama,Romance,Sci-Fi', 'Drama,Romance,Sci-Fi',
#        'Comedy,Drama,Sci-Fi', 'Adventure,Drama,Sci-Fi',
#        'Action,Award Winning,Drama,Romance,Sci-Fi',
#        'Action,Drama,Romance,Sci-Fi',
#        'Action,Adventure,Drama,Romance,Sci-Fi',
#        'Adventure,Comedy,Drama,Romance,Sci-Fi,Sports',
#        'Action,Adventure,Sci-Fi',
#        'Action,Comedy,Drama,Fantasy,Girls Love,Romance',
#        'Comedy,Drama,Fantasy', 'Comedy,Drama,Fantasy,Romance',
#        'Drama,Romance,Slice of Life,Supernatural',
#        'Adventure,Comedy,Fantasy,Romance',
#        'Adventure,Drama,Horror,Romance,Supernatural,Suspense',
#        'Comedy,Romance,Slice of Life', 'Adventure,Comedy,Fantasy,Sci-Fi',
#        'Adventure,Comedy,Fantasy', 'Action,Comedy,Drama,Gourmet',
#        'Action,Adventure,Comedy,Fantasy,Sci-Fi,Ecchi',
#        'Action,Romance,Sci-Fi', 'Drama,Fantasy,Romance',
#        'Action,Adventure,Drama,Fantasy',
#        'Comedy,Drama,Romance,Supernatural',
#        'Adventure,Comedy,Drama,Fantasy,Romance',
#        'Adventure,Drama,Fantasy,Romance', 'Action,Comedy,Fantasy,Sci-Fi',
#        'Action,Adventure,Comedy,Drama,Supernatural',
#        'Action,Comedy,Drama,Mystery,Supernatural',
#        'Comedy,Romance,Slice of Life,Ecchi', 'Comedy,Drama,Supernatural',
#        'Sci-Fi', 'Action,Drama,Mystery,Romance,Supernatural',
#        'Drama,Girls Love,Romance,Supernatural',
#        'Drama,Romance,Slice of Life',
#        'Action,Boys Love,Drama,Mystery,Supernatural',
#        'Action,Drama,Horror,Mystery,Supernatural',
#        'Action,Comedy,Girls Love,Sci-Fi,Ecchi',
#        'Action,Adventure,Comedy,Supernatural',
#        'Action,Drama,Fantasy,Horror,Sci-Fi,Supernatural',
#        'Action,Drama,Fantasy,Romance',
#        'Comedy,Fantasy,Romance,Supernatural,Ecchi', 'Drama,Girls Love',
#        'Adventure,Fantasy,Horror,Sci-Fi,Supernatural',
#        'Adventure,Drama,Fantasy,Sci-Fi', 'Comedy,Fantasy,Romance',
#        'Action,Adventure,Award Winning,Fantasy',
#        'Action,Drama,Mystery,Romance,Sci-Fi',
#        'Adventure,Comedy,Drama,Fantasy,Sci-Fi',
#        'Action,Adventure,Drama,Sci-Fi',
#        'Action,Horror,Mystery,Romance,Supernatural',
#        'Adventure,Drama,Fantasy', 'Comedy,Drama,Mystery,Supernatural',
#        'Action,Comedy,Ecchi', 'Action,Adventure,Romance,Sci-Fi',
#        'Adventure,Romance', 'Action,Sci-Fi,Ecchi',
#        'Adventure,Fantasy,Romance', 'Comedy,Mystery,Supernatural,Hentai',
#        'Comedy,Romance,Ecchi', 'Comedy,Drama,Romance,Ecchi',
#        'Adventure,Comedy,Romance', 'Adventure,Sci-Fi', 'Action,Mystery',
#        'Adventure,Award Winning,Supernatural',
#        'Action,Adventure,Drama,Fantasy,Mystery,Sci-Fi',
#        'Adventure,Fantasy,Hentai', 'Action,Adventure,Comedy',
#        'Action,Adventure,Drama,Fantasy,Romance',
#        'Action,Adventure,Fantasy,Supernatural',
#        'Action,Adventure,Mystery,Sci-Fi', 'Comedy,Fantasy,Slice of Life',
#        'Hentai', 'Action,Adventure,Comedy,Sci-Fi',
#        'Comedy,Romance,Hentai', 'Comedy,Drama,Romance,Hentai',
#        'Horror,Hentai', 'Action,Comedy,Sci-Fi,Hentai',
#        'Action,Adventure,Comedy,Mystery,Sci-Fi',
#        'Action,Adventure,Comedy,Fantasy,Sci-Fi',
#        'Action,Drama,Horror,Romance,Supernatural',
#        'Action,Avant Garde,Comedy,Sci-Fi', 'Horror,Mystery,Supernatural',
#        'Action,Comedy,Fantasy,Supernatural', 'Comedy,Sci-Fi',
#        'Adventure,Sports', 'Adventure,Comedy,Mystery',
#        'Adventure,Comedy,Drama,Sci-Fi,Supernatural', 'Action,Adventure',
#        'Drama,Mystery,Sci-Fi,Supernatural,Suspense',
#        'Comedy,Fantasy,Romance,Ecchi', 'Boys Love,Comedy', 'Mystery',
#        'Comedy,Drama', 'Fantasy,Supernatural',
#        'Action,Adventure,Comedy,Fantasy,Romance,Supernatural',
#        'Adventure,Comedy,Supernatural', 'Drama,Mystery,Supernatural',
#        'Ecchi', 'Drama,Horror', 'Adventure,Comedy,Ecchi',
#        'Action,Horror,Supernatural', 'Action,Drama,Mystery',
#        'Drama,Slice of Life', 'Fantasy,Horror,Mystery,Supernatural',
#        'Action,Drama,Mystery,Romance', 'Action,Adventure,Comedy,Sports',
#        'Drama,Sports', 'Comedy,Fantasy,Sci-Fi',
#        'Adventure,Comedy,Drama,Sci-Fi', 'Action,Adventure,Comedy,Ecchi',
#        'Mystery,Sci-Fi', 'Action,Fantasy,Horror,Romance',
#        'Action,Adventure,Comedy,Mystery', 'Comedy,Supernatural',
#        'Award Winning,Comedy,Fantasy,Ecchi', 'Comedy,Fantasy',
#        'Drama,Fantasy,Mystery,Sci-Fi', 'Drama,Romance,Sports',
#        'Comedy,Girls Love,Hentai', 'Action,Fantasy',
#        'Action,Drama,Hentai', 'Action,Comedy,Sci-Fi,Ecchi',
#        'Avant Garde,Drama,Mystery,Supernatural,Suspense',
#        'Comedy,Mystery,Supernatural', 'Fantasy',
#        'Avant Garde,Award Winning,Drama,Mystery,Sci-Fi,Supernatural',
#        'Drama,Mystery', 'Drama,Sci-Fi,Supernatural',
#        'Action,Adventure,Fantasy,Sci-Fi', 'Drama,Fantasy,Supernatural',
#        'Comedy,Sci-Fi,Ecchi', 'Action,Fantasy,Romance,Supernatural',
#        'Comedy,Ecchi', 'Adventure,Drama,Fantasy,Supernatural',
#        'Boys Love,Comedy,Mystery,Romance',
#        'Avant Garde,Drama,Horror,Mystery,Supernatural',
#        'Action,Comedy,Romance,Sci-Fi,Ecchi',
#        'Drama,Horror,Supernatural,Ecchi',
#        'Action,Drama,Horror,Sci-Fi,Supernatural,Ecchi',
#        'Drama,Fantasy,Sci-Fi,Supernatural', 'Comedy,Romance,Sports',
#        'Drama,Fantasy,Mystery,Slice of Life', 'Adventure,Fantasy',
#        'Action,Comedy,Supernatural',
#        'Adventure,Drama,Fantasy,Romance,Sci-Fi',
#        'Action,Adventure,Comedy,Fantasy,Ecchi',
#        'Award Winning,Horror,Supernatural', 'Sci-Fi,Sports',
#        'Comedy,Drama,Mystery', 'Action,Adventure,Drama,Fantasy,Sci-Fi',
#        'Comedy,Slice of Life,Ecchi', 'Horror,Sci-Fi',
#        'Award Winning,Comedy,Slice of Life',
#        'Action,Adventure,Award Winning,Comedy,Drama,Romance',
#        'Adventure,Comedy', 'Boys Love,Comedy,Sports',
#        'Action,Adventure,Comedy,Fantasy', 'Adventure,Comedy,Drama',
#        'Award Winning,Comedy,Drama,Fantasy',
#        'Adventure,Award Winning,Drama,Fantasy,Romance',
#        'Award Winning,Drama,Romance,Sci-Fi',
#        'Adventure,Comedy,Drama,Fantasy', 'Avant Garde,Drama,Horror',
#        'Comedy,Drama,Fantasy,Mystery',
#        'Avant Garde,Drama,Fantasy,Girls Love,Romance',
#        'Adventure,Drama,Romance,Supernatural',
#        'Action,Adventure,Comedy,Drama,Fantasy,Romance,Supernatural',
#        'Adventure,Fantasy,Mystery,Romance,Sci-Fi,Suspense',
#        'Adventure,Fantasy,Mystery,Slice of Life,Supernatural',
#        'Action,Award Winning,Sci-Fi', 'Action,Adventure,Drama',
#        'Drama,Romance,Sports,Supernatural',
#        'Fantasy,Sci-Fi,Slice of Life',
#        'Action,Romance,Sci-Fi,Supernatural',
#        'Action,Adventure,Supernatural', 'Action,Comedy,Fantasy',
#        'Adventure,Supernatural', 'Action,Adventure,Slice of Life',
#        'Award Winning,Comedy,Drama,Slice of Life,Supernatural',
#        'Adventure,Comedy,Fantasy,Supernatural,Ecchi',
#        'Adventure,Fantasy,Girls Love,Mystery,Ecchi',
#        'Adventure,Horror,Romance,Supernatural',
#        'Action,Adventure,Drama,Romance',
#        'Adventure,Award Winning,Comedy,Drama,Fantasy',
#        'Adventure,Award Winning,Fantasy,Romance,Sci-Fi',
#        'Drama,Horror,Romance,Supernatural', 'Unknown', 'Romance',
#        'Action,Adventure,Comedy,Drama,Fantasy', 'Fantasy,Romance',
#        'Comedy,Romance,Sci-Fi',
#        'Action,Drama,Fantasy,Horror,Romance,Sci-Fi',
#        'Drama,Romance,Supernatural',
#        'Boys Love,Comedy,Drama,Fantasy,Horror',
#        'Adventure,Comedy,Drama,Romance',
#        'Comedy,Girls Love,Romance,Sci-Fi', 'Comedy,Drama,Sports',
#        'Action,Mystery,Sci-Fi', 'Award Winning,Drama,Romance',
#        'Adventure,Award Winning,Fantasy',
#        'Action,Adventure,Comedy,Drama,Romance,Sci-Fi', 'Fantasy,Sci-Fi',
#        'Adventure,Drama,Sci-Fi,Slice of Life', 'Fantasy,Horror,Mystery',
#        'Comedy,Romance,Supernatural,Ecchi',
#        'Drama,Fantasy,Mystery,Romance,Supernatural',
#        'Adventure,Award Winning,Drama,Fantasy',
#        'Boys Love,Drama,Supernatural', 'Avant Garde,Award Winning,Comedy',
#        'Adventure,Comedy,Fantasy,Supernatural',
#        'Comedy,Drama,Supernatural,Ecchi', 'Sci-Fi,Slice of Life',
#        'Drama,Fantasy', 'Adventure,Fantasy,Horror,Romance,Supernatural',
#        'Adventure,Horror,Supernatural',
#        'Action,Sci-Fi,Supernatural,Suspense',
#        'Drama,Fantasy,Horror,Mystery', 'Action,Horror,Mystery',
#        'Comedy,Fantasy,Romance,Sci-Fi', 'Adventure,Drama,Romance',
#        'Action,Adventure,Comedy,Drama', 'Romance,Ecchi',
#        'Adventure,Drama,Fantasy,Romance,Supernatural',
#        'Comedy,Drama,Romance,Sci-Fi', 'Suspense',
#        'Adventure,Drama,Fantasy,Horror,Supernatural',
#        'Comedy,Drama,Girls Love,Romance,Slice of Life',
#        'Drama,Supernatural', 'Drama,Romance,Sci-Fi,Slice of Life',
#        'Fantasy,Romance,Sci-Fi', 'Action,Drama,Horror',
#        'Action,Comedy,Drama,Romance,Slice of Life,Sports',
#        'Romance,Hentai', 'Action,Comedy,Drama,Sci-Fi,Ecchi',
#        'Action,Adventure,Fantasy,Sci-Fi,Slice of Life',
#        'Boys Love,Drama,Sci-Fi,Erotica',
#        'Comedy,Drama,Fantasy,Mystery,Romance',
#        'Boys Love,Drama,Horror,Hentai', 'Boys Love,Drama',
#        'Action,Horror,Sci-Fi,Supernatural', 'Boys Love,Drama,Erotica',
#        'Boys Love,Drama,Romance,Erotica', 'Boys Love,Drama,Hentai',
#        'Boys Love,Comedy,Drama,Romance,Hentai',
#        'Boys Love,Comedy,Drama,Romance,Erotica', 'Boys Love,Hentai',
#        'Award Winning,Comedy,Drama', 'Adventure,Comedy,Sci-Fi,Sports',
#        'Adventure,Comedy,Sci-Fi,Ecchi', 'Comedy,Sci-Fi,Slice of Life',
#        'Action,Adventure,Comedy,Fantasy,Romance,Ecchi', 'Comedy,Sports',
#        'Adventure,Drama', 'Drama,Suspense', 'Action,Comedy,Horror',
#        'Comedy,Mystery,Sci-Fi,Slice of Life',
#        'Boys Love,Comedy,Drama,Romance',
#        'Action,Adventure,Comedy,Romance,Sci-Fi',
#        'Drama,Girls Love,Romance', 'Action,Drama,Fantasy,Sci-Fi',
#        'Action,Ecchi', 'Comedy,Drama,Slice of Life,Ecchi',
#        'Adventure,Avant Garde,Award Winning,Comedy,Romance',
#        'Action,Adventure,Drama,Mystery',
#        'Drama,Fantasy,Girls Love,Romance', 'Avant Garde,Drama,Fantasy',
#        'Boys Love,Comedy,Drama', 'Adventure',
#        'Action,Comedy,Horror,Mystery,Supernatural',
#        'Horror,Mystery,Supernatural,Suspense',
#        'Drama,Fantasy,Slice of Life', 'Action,Comedy,Drama,Sci-Fi',
#        'Action,Adventure,Drama,Mystery,Sci-Fi',
#        'Action,Adventure,Drama,Fantasy,Mystery,Romance,Supernatural',
#        'Supernatural,Hentai', 'Action,Boys Love,Sci-Fi,Hentai',
#        'Action,Adventure,Horror,Sci-Fi', 'Action,Comedy,Romance,Ecchi',
#        'Action,Adventure,Comedy,Drama,Horror,Mystery,Romance,Sci-Fi,Ecchi',
#        'Action,Comedy,Drama,Horror,Mystery,Sci-Fi,Supernatural,Ecchi',
#        'Action,Comedy,Romance,Sci-Fi',
#        'Action,Adventure,Comedy,Romance,Supernatural',
#        'Mystery,Supernatural',
#        'Action,Boys Love,Drama,Romance,Supernatural',
#        'Adventure,Drama,Sci-Fi,Supernatural',
#        'Adventure,Comedy,Sci-Fi,Slice of Life', 'Award Winning',
#        'Action,Adventure,Award Winning,Drama,Fantasy,Romance',
#        'Adventure,Boys Love,Comedy,Fantasy', 'Romance,Supernatural',
#        'Action,Fantasy,Supernatural',
#        'Boys Love,Drama,Romance,Sports,Erotica',
#        'Action,Mystery,Supernatural', 'Adventure,Comedy,Fantasy,Ecchi',
#        'Horror,Supernatural', 'Award Winning,Drama,Fantasy',
#        'Drama,Romance,Slice of Life,Sports', 'Action,Romance,Ecchi',
#        'Action,Drama,Sci-Fi,Suspense',
#        'Comedy,Drama,Mystery,Sci-Fi,Ecchi', 'Drama,Slice of Life,Sports',
#        'Adventure,Horror,Mystery', 'Adventure,Comedy,Romance,Sci-Fi',
#        'Comedy,Gourmet,Slice of Life',
#        'Award Winning,Drama,Mystery,Sci-Fi', 'Drama,Supernatural,Ecchi',
#        'Action,Adventure,Drama,Horror', 'Award Winning,Drama',
#        'Romance,Sci-Fi', 'Action,Drama,Fantasy,Romance,Sci-Fi',
#        'Action,Adventure,Drama,Horror,Mystery,Sci-Fi',
#        'Action,Drama,Mystery,Sci-Fi', 'Adventure,Horror',
#        'Comedy,Sci-Fi,Sports', 'Adventure,Sci-Fi,Supernatural',
#        'Action,Fantasy,Romance', 'Action,Comedy,Sci-Fi,Sports,Ecchi',
#        'Action,Adventure,Comedy,Drama,Sci-Fi,Sports',
#        'Action,Adventure,Fantasy,Romance,Sci-Fi',
#        'Boys Love,Drama,Romance', 'Action,Comedy,Sci-Fi,Slice of Life',
#        'Action,Adventure,Fantasy,Romance,Sci-Fi,Supernatural',
#        'Action,Adventure,Fantasy,Horror,Romance',
#        'Horror,Sci-Fi,Supernatural',
#        'Action,Comedy,Fantasy,Supernatural,Ecchi',
#        'Action,Comedy,Romance', 'Drama,Mystery,Sci-Fi,Supernatural',
#        'Action,Drama,Sci-Fi,Supernatural',
#        'Action,Drama,Horror,Sci-Fi,Supernatural',
#        'Action,Drama,Mystery,Suspense',
#        'Action,Adventure,Drama,Mystery,Romance,Sci-Fi',
#        'Drama,Fantasy,Romance,Hentai', 'Action,Horror',
#        'Fantasy,Romance,Hentai', 'Comedy,Fantasy,Horror,Supernatural',
#        'Action,Comedy,Drama,Romance,Sports',
#        'Action,Adventure,Comedy,Fantasy,Supernatural,Hentai',
#        'Fantasy,Hentai', 'Action,Adventure,Drama,Horror,Sci-Fi',
#        'Action,Adventure,Horror,Mystery,Sci-Fi,Suspense',
#        'Adventure,Fantasy,Horror,Hentai', 'Adventure,Mystery',
#        'Comedy,Mystery',
#        'Avant Garde,Award Winning,Comedy,Fantasy,Suspense',
#        'Action,Comedy,Fantasy,Horror,Romance,Supernatural,Hentai',
#        'Drama,Sci-Fi,Sports', 'Drama,Romance,Hentai', 'Girls Love,Hentai',
#        'Action,Adventure,Award Winning,Comedy,Mystery',
#        'Award Winning,Drama,Fantasy,Mystery',
#        'Action,Adventure,Fantasy,Sci-Fi,Supernatural',
#        'Action,Supernatural,Suspense',
#        'Action,Horror,Romance,Supernatural', 'Action,Adventure,Mystery',
#        'Award Winning,Drama,Horror,Sci-Fi', 'Action,Comedy,Mystery',
#        'Adventure,Drama,Mystery', 'Action,Fantasy,Horror,Supernatural',
#        'Horror,Mystery,Sci-Fi', 'Comedy,Fantasy,Girls Love,Ecchi',
#        'Comedy,Drama,Horror,Supernatural,Ecchi', 'Drama,Horror,Sci-Fi',
#        'Sports,Hentai',
#        'Action,Comedy,Drama,Fantasy,Horror,Romance,Sci-Fi',
#        'Drama,Fantasy,Slice of Life,Supernatural',
#        'Supernatural,Suspense', 'Romance,Sports',
#        'Adventure,Comedy,Fantasy,Romance,Supernatural,Ecchi',
#        'Comedy,Slice of Life,Supernatural', 'Drama,Mystery,Sci-Fi',
#        'Fantasy,Horror,Supernatural', 'Comedy,Fantasy,Hentai',
#        'Action,Comedy,Drama,Fantasy,Horror,Ecchi',
#        'Adventure,Comedy,Drama,Fantasy,Romance,Sci-Fi', 'Supernatural',
#        'Drama,Gourmet,Slice of Life', 'Action,Comedy,Sports,Ecchi',
#        'Drama,Sci-Fi,Ecchi',
#        'Adventure,Drama,Horror,Mystery,Sci-Fi,Supernatural',
#        'Adventure,Comedy,Romance,Sci-Fi,Ecchi', 'Adventure,Sci-Fi,Ecchi',
#        'Boys Love,Drama,Fantasy,Romance,Sci-Fi,Supernatural',
#        'Action,Horror,Sci-Fi,Ecchi',
#        'Action,Comedy,Fantasy,Horror,Supernatural',
#        'Adventure,Drama,Slice of Life',
#        'Action,Adventure,Mystery,Sci-Fi,Supernatural',
#        'Action,Sci-Fi,Supernatural',
#        'Action,Adventure,Comedy,Sci-Fi,Sports',
#        'Horror,Supernatural,Hentai',
#        'Adventure,Drama,Horror,Sci-Fi,Supernatural',
#        'Action,Comedy,Sci-Fi,Sports', 'Action,Adventure,Fantasy,Hentai',
#        'Adventure,Comedy,Gourmet', 'Sci-Fi,Hentai', 'Drama,Hentai',
#        'Action,Avant Garde,Drama,Sci-Fi',
#        'Comedy,Drama,Romance,Slice of Life,Supernatural',
#        'Action,Comedy,Drama,Fantasy', 'Adventure,Fantasy,Slice of Life',
#        'Action,Drama,Fantasy,Horror,Supernatural',
#        'Mystery,Supernatural,Suspense', 'Drama,Fantasy,Sci-Fi',
#        'Fantasy,Romance,Supernatural',
#        'Drama,Fantasy,Romance,Supernatural',
#        'Comedy,Fantasy,Supernatural', 'Boys Love,Romance',
#        'Boys Love,Comedy,Romance', 'Slice of Life',
#        'Action,Mystery,Romance,Sci-Fi',
#        'Avant Garde,Fantasy,Horror,Mystery,Sci-Fi,Suspense',
#        'Action,Adventure,Comedy,Drama,Romance,Sci-Fi,Ecchi',
#        'Action,Adventure,Drama,Fantasy,Supernatural',
#        'Avant Garde,Mystery,Supernatural', 'Avant Garde,Fantasy',
#        'Sci-Fi,Ecchi', 'Adventure,Romance,Sci-Fi',
#        'Award Winning,Comedy,Drama,Sci-Fi',
#        'Action,Adventure,Award Winning,Comedy,Sci-Fi',
#        'Comedy,Drama,Slice of Life,Supernatural',
#        'Action,Comedy,Drama,Slice of Life,Sports',
#        'Adventure,Comedy,Horror,Romance,Supernatural', 'Horror,Mystery',
#        'Adventure,Comedy,Hentai', 'Avant Garde,Comedy,Sci-Fi',
#        'Action,Adventure,Comedy,Mystery,Romance',
#        'Action,Adventure,Comedy,Fantasy,Romance', 'Action,Comedy,Sports',
#        'Adventure,Drama,Mystery,Slice of Life', 'Action,Sci-Fi,Hentai',
#        'Horror', 'Adventure,Comedy,Slice of Life',
#        'Romance,Slice of Life',
#        'Comedy,Drama,Fantasy,Romance,Slice of Life,Ecchi',
#        'Adventure,Comedy,Slice of Life,Supernatural',
#        'Action,Comedy,Horror,Supernatural', 'Action,Hentai',
#        'Fantasy,Supernatural,Hentai', 'Comedy,Horror,Romance,Sci-Fi',
#        'Adventure,Comedy,Fantasy,Slice of Life',
#        'Comedy,Drama,Fantasy,Sci-Fi',
#        'Action,Adventure,Award Winning,Supernatural',
#        'Adventure,Award Winning,Comedy,Drama,Mystery,Sci-Fi',
#        'Comedy,Fantasy,Horror', 'Action,Girls Love,Sci-Fi',
#        'Action,Adventure,Romance', 'Action,Horror,Sci-Fi',
#        'Comedy,Romance,Slice of Life,Sports', 'Horror,Mystery,Suspense',
#        'Boys Love,Drama,Romance,Slice of Life,Erotica',
#        'Avant Garde,Boys Love,Drama,Romance', 'Fantasy,Slice of Life',
#        'Erotica', 'Action,Comedy,Mystery,Supernatural',
#        'Adventure,Comedy,Fantasy,Mystery,Sci-Fi', 'Action,Sci-Fi,Sports',
#        'Adventure,Comedy,Fantasy,Gourmet',
#        'Action,Adventure,Horror,Sci-Fi,Hentai', 'Comedy,Girls Love,Ecchi',
#        'Adventure,Sci-Fi,Hentai',
#        'Action,Adventure,Comedy,Romance,Sci-Fi,Ecchi',
#        'Fantasy,Horror,Sci-Fi,Hentai', 'Fantasy,Horror,Hentai',
#        'Action,Avant Garde,Drama,Horror', 'Fantasy,Mystery,Supernatural',
#        'Comedy,Supernatural,Ecchi', 'Comedy,Fantasy,Sports',
#        'Action,Drama,Slice of Life,Sports', 'Comedy,Drama,Ecchi',
#        'Comedy,Hentai', 'Action,Fantasy,Hentai', 'Comedy,Fantasy,Ecchi',
#        'Comedy,Romance,Slice of Life,Supernatural,Ecchi',
#        'Action,Comedy,Fantasy,Romance,Sci-Fi,Ecchi',
#        'Adventure,Fantasy,Ecchi', 'Drama,Fantasy,Romance,Sci-Fi',
#        'Drama,Fantasy,Mystery,Romance',
#        'Comedy,Romance,Sci-Fi,Slice of Life', 'Adventure,Slice of Life',
#        'Avant Garde,Comedy,Slice of Life',
#        'Action,Boys Love,Horror,Sci-Fi,Supernatural',
#        'Action,Mystery,Supernatural,Suspense', 'Drama,Romance,Ecchi',
#        'Mystery,Sci-Fi,Supernatural,Suspense', 'Comedy,Sports,Ecchi',
#        'Comedy,Fantasy,Sci-Fi,Sports',
#        'Award Winning,Comedy,Fantasy,Sci-Fi',
#        'Adventure,Award Winning,Comedy,Fantasy,Sci-Fi',
#        'Comedy,Sci-Fi,Hentai', 'Action,Drama,Fantasy,Horror,Mystery',
#        'Action,Award Winning,Drama', 'Action,Drama,Suspense',
#        'Action,Award Winning,Drama,Sci-Fi',
#        'Action,Comedy,Drama,Fantasy,Romance',
#        'Action,Adventure,Fantasy,Romance', 'Drama,Romance,Sci-Fi,Hentai',
#        'Action,Award Winning,Comedy',
#        'Adventure,Comedy,Drama,Fantasy,Sci-Fi,Slice of Life,Supernatural',
#        'Adventure,Boys Love,Comedy', 'Adventure,Fantasy,Romance,Hentai',
#        'Adventure,Award Winning', 'Action,Drama,Sports',
#        'Drama,Mystery,Romance', 'Mystery,Slice of Life,Supernatural',
#        'Avant Garde,Fantasy,Horror,Hentai', 'Comedy,Girls Love',
#        'Girls Love,Supernatural,Hentai', 'Drama,Girls Love,Sci-Fi',
#        'Comedy,Mystery,Supernatural,Ecchi',
#        'Adventure,Drama,Fantasy,Horror,Mystery,Supernatural',
#        'Action,Horror,Supernatural,Hentai', 'Comedy,Gourmet,Supernatural',
#        'Boys Love', 'Action,Fantasy,Mystery,Romance',
#        'Boys Love,Comedy,Fantasy,Romance,Supernatural',
#        'Action,Adventure,Suspense', 'Action,Romance,Sports',
#        'Adventure,Comedy,Fantasy,Hentai', 'Comedy,Horror',
#        'Action,Comedy,Fantasy,Romance,Ecchi',
#        'Action,Fantasy,Horror,Sci-Fi',
#        'Comedy,Romance,Slice of Life,Supernatural',
#        'Adventure,Drama,Fantasy,Horror,Sci-Fi,Supernatural',
#        'Action,Adventure,Fantasy,Horror,Supernatural',
#        'Boys Love,Comedy,Romance,Erotica', 'Avant Garde,Drama',
#        'Comedy,Fantasy,Sci-Fi,Hentai', 'Action,Drama,Supernatural',
#        'Action,Drama,Horror,Mystery,Romance,Sci-Fi,Hentai',
#        'Adventure,Comedy,Sports', 'Action,Comedy,Fantasy,Hentai',
#        'Mystery,Hentai', 'Avant Garde,Award Winning,Drama',
#        'Action,Girls Love,Horror,Sci-Fi,Supernatural',
#        'Drama,Mystery,Romance,Hentai', 'Action,Comedy,Hentai',
#        'Drama,Fantasy,Supernatural,Suspense', 'Girls Love,Romance',
#        'Drama,Mystery,Romance,Supernatural', 'Adventure,Fantasy,Suspense',
#        'Award Winning,Comedy', 'Action,Supernatural,Hentai',
#        'Avant Garde,Sci-Fi', 'Avant Garde,Drama,Supernatural',
#        'Action,Avant Garde,Fantasy,Romance,Sci-Fi',
#        'Romance,Slice of Life,Supernatural', 'Award Winning,Fantasy',
#        'Action,Avant Garde,Horror,Sci-Fi', 'Action,Adventure,Horror',
#        'Action,Romance', 'Fantasy,Ecchi',
#        'Action,Comedy,Drama,Fantasy,Supernatural',
#        'Action,Boys Love,Supernatural',
#        'Adventure,Award Winning,Mystery,Romance,Sci-Fi',
#        'Award Winning,Mystery',
#        'Action,Mystery,Romance,Supernatural,Suspense',
#        'Action,Drama,Mystery,Supernatural,Suspense',
#        'Action,Award Winning,Drama,Sci-Fi,Suspense',
#        'Adventure,Comedy,Romance,Sports', 'Fantasy,Mystery,Romance',
#        'Sci-Fi,Supernatural', 'Action,Comedy,Fantasy,Ecchi',
#        'Action,Comedy,Romance,Supernatural,Hentai',
#        'Avant Garde,Fantasy,Romance',
#        'Action,Comedy,Romance,Supernatural,Ecchi',
#        'Fantasy,Horror,Supernatural,Hentai',
#        'Action,Fantasy,Mystery,Ecchi', 'Boys Love,Comedy,Gourmet',
#        'Action,Adventure,Drama,Suspense',
#        'Drama,Slice of Life,Supernatural', 'Avant Garde,Horror',
#        'Award Winning,Fantasy,Horror,Supernatural',
#        'Action,Fantasy,Supernatural,Hentai',
#        'Adventure,Drama,Fantasy,Slice of Life',
#        'Adventure,Comedy,Romance,Supernatural,Ecchi',
#        'Award Winning,Romance', 'Action,Adventure,Fantasy,Ecchi',
#        'Action,Drama,Mystery,Romance,Supernatural,Suspense',
#        'Horror,Sci-Fi,Supernatural,Hentai', 'Sci-Fi,Supernatural,Hentai',
#        'Adventure,Award Winning,Comedy,Fantasy', 'Avant Garde',
#        'Drama,Horror,Romance', 'Avant Garde,Comedy,Drama,Sci-Fi',
#        'Action,Adventure,Comedy,Fantasy,Sci-Fi,Supernatural',
#        'Drama,Fantasy,Suspense', 'Avant Garde,Comedy',
#        'Comedy,Horror,Supernatural',
#        'Adventure,Comedy,Fantasy,Romance,Supernatural',
#        'Adventure,Mystery,Romance,Sci-Fi',
#        'Action,Drama,Romance,Suspense', 'Mystery,Sci-Fi,Supernatural',
#        'Adventure,Comedy,Horror', 'Action,Comedy,Girls Love,Ecchi',
#        'Comedy,Drama,Romance,Sports',
#        'Action,Drama,Horror,Romance,Sci-Fi',
#        'Mystery,Romance,Supernatural', 'Adventure,Award Winning,Drama',
#        'Boys Love,Romance,Slice of Life,Sports', 'Action,Romance,Hentai',
#        'Girls Love,Slice of Life',
#        'Action,Adventure,Avant Garde,Mystery,Supernatural',
#        'Mystery,Suspense', 'Adventure,Comedy,Fantasy,Sports',
#        'Adventure,Suspense', 'Action,Comedy,Drama,Romance',
#        'Action,Fantasy,Sci-Fi,Supernatural', 'Action,Avant Garde',
#        'Adventure,Fantasy,Mystery,Supernatural',
#        'Adventure,Fantasy,Slice of Life,Supernatural',
#        'Action,Fantasy,Ecchi', 'Drama,Supernatural,Hentai',
#        'Mystery,Romance,Sci-Fi,Suspense', 'Romance,Sports,Hentai',
#        'Award Winning,Comedy,Sci-Fi',
#        'Action,Comedy,Fantasy,Slice of Life',
#        'Adventure,Comedy,Fantasy,Horror,Supernatural',
#        'Boys Love,Comedy,Drama,Supernatural,Erotica',
#        'Comedy,Girls Love,Slice of Life,Ecchi',
#        'Drama,Fantasy,Horror,Mystery,Supernatural',
#        'Comedy,Romance,Sci-Fi,Supernatural,Ecchi',
#        'Drama,Gourmet,Romance,Slice of Life',
#        'Action,Comedy,Fantasy,Romance,Sci-Fi',
#        'Action,Adventure,Drama,Slice of Life',
#        'Action,Adventure,Supernatural,Ecchi', 'Fantasy,Horror',
#        'Comedy,Horror,Mystery,Supernatural',
#        'Girls Love,Romance,Slice of Life', 'Comedy,Girls Love,Romance',
#        'Action,Comedy,Girls Love,Romance,Ecchi',
#        'Fantasy,Romance,Slice of Life', 'Action,Drama,Fantasy',
#        'Action,Comedy,Fantasy,Romance,Supernatural,Ecchi', 'Gourmet',
#        'Sports,Ecchi',
#        'Action,Adventure,Comedy,Drama,Fantasy,Romance,Ecchi',
#        'Action,Supernatural,Ecchi', 'Avant Garde,Romance',
#        'Boys Love,Erotica', 'Action,Mystery,Romance,Suspense',
#        'Award Winning,Supernatural', 'Action,Drama,Fantasy,Supernatural',
#        'Romance,Slice of Life,Ecchi', 'Avant Garde,Fantasy,Sci-Fi',
#        'Action,Adventure,Comedy,Gourmet',
#        'Comedy,Mystery,Sci-Fi,Supernatural',
#        'Adventure,Boys Love,Drama,Fantasy',
#        'Action,Horror,Mystery,Supernatural', 'Drama,Fantasy,Mystery',
#        'Action,Adventure,Comedy,Romance,Supernatural,Ecchi',
#        'Avant Garde,Drama,Romance', 'Award Winning,Drama,Supernatural',
#        'Mystery,Sci-Fi,Suspense', 'Award Winning,Comedy,Mystery,Romance',
#        'Comedy,Sci-Fi,Supernatural,Ecchi',
#        'Adventure,Avant Garde,Comedy,Fantasy,Mystery',
#        'Adventure,Fantasy,Romance,Sci-Fi,Supernatural',
#        'Action,Horror,Supernatural,Ecchi',
#        'Award Winning,Drama,Slice of Life,Supernatural',
#        'Sports,Supernatural', 'Adventure,Fantasy,Horror,Supernatural',
#        'Adventure,Comedy,Horror,Supernatural',
#        'Action,Horror,Mystery,Supernatural,Suspense',
#        'Boys Love,Comedy,Erotica', 'Adventure,Ecchi',
#        'Action,Boys Love,Sci-Fi', 'Action,Award Winning,Supernatural',
#        'Action,Adventure,Comedy,Fantasy,Sports',
#        'Drama,Sci-Fi,Slice of Life', 'Action,Comedy,Supernatural,Ecchi',
#        'Action,Comedy,Drama,Sports', 'Drama,Sci-Fi,Suspense',
#        'Action,Drama,Romance,Sci-Fi,Ecchi', 'Gourmet,Slice of Life',
#        'Girls Love,Ecchi', 'Slice of Life,Supernatural',
#        'Award Winning,Drama,Suspense', 'Action,Boys Love,Drama,Erotica',
#        'Comedy,Drama,Romance,Sci-Fi,Supernatural,Ecchi',
#        'Fantasy,Romance,Supernatural,Hentai', 'Avant Garde,Comedy,Horror',
#        'Action,Adventure,Comedy,Fantasy,Gourmet',
#        'Action,Boys Love,Drama,Mystery,Sci-Fi', 'Action,Mystery,Suspense',
#        'Slice of Life,Sports', 'Action,Comedy,Gourmet',
#        'Award Winning,Drama,Romance,Supernatural',
#        'Action,Comedy,Drama,Fantasy,Romance,Sci-Fi',
#        'Drama,Mystery,Romance,Slice of Life',
#        'Drama,Fantasy,Romance,Ecchi', 'Action,Comedy,Mystery,Romance',
#        'Action,Mystery,Sci-Fi,Supernatural',
#        'Avant Garde,Comedy,Drama,Mystery',
#        'Action,Avant Garde,Comedy,Supernatural,Ecchi',
#        'Action,Sports,Supernatural', 'Adventure,Comedy,Romance,Ecchi',
#        'Fantasy,Supernatural,Ecchi', 'Boys Love,Drama,Romance,Sci-Fi',
#        'Adventure,Fantasy,Romance,Ecchi',
#        'Action,Boys Love,Fantasy,Supernatural',
#        'Action,Adventure,Fantasy,Mystery,Sci-Fi',
#        'Comedy,Horror,Romance,Supernatural,Ecchi',
#        'Adventure,Drama,Mystery,Supernatural', 'Action,Sports,Ecchi',
#        'Action,Drama,Horror,Romance,Sci-Fi,Supernatural',
#        'Horror,Supernatural,Suspense', 'Adventure,Comedy,Mystery,Sports',
#        'Boys Love,Sci-Fi,Slice of Life', 'Mystery,Slice of Life',
#        'Award Winning,Fantasy,Slice of Life',
#        'Horror,Mystery,Romance,Supernatural',
#        'Adventure,Award Winning,Sci-Fi',
#        'Adventure,Boys Love,Comedy,Romance', 'Mystery,Romance,Ecchi',
#        'Drama,Horror,Mystery,Sci-Fi,Supernatural',
#        'Action,Adventure,Award Winning,Comedy,Ecchi',
#        'Award Winning,Drama,Fantasy,Slice of Life',
#        'Comedy,Drama,Mystery,Romance,Slice of Life',
#        'Comedy,Mystery,Romance,Ecchi',
#        'Adventure,Mystery,Sci-Fi,Supernatural', 'Action,Sci-Fi,Suspense',
#        'Award Winning,Slice of Life', 'Comedy,Mystery,Sports',
#        'Action,Drama,Mystery,Sci-Fi,Suspense',
#        'Adventure,Comedy,Drama,Mystery,Sci-Fi',
#        'Action,Drama,Fantasy,Mystery', 'Action,Sci-Fi,Slice of Life',
#        'Action,Adventure,Mystery,Supernatural',
#        'Drama,Supernatural,Suspense', 'Comedy,Drama,Horror,Romance',
#        'Boys Love,Fantasy',
#        'Action,Boys Love,Comedy,Fantasy,Mystery,Supernatural',
#        'Adventure,Fantasy,Mystery', 'Action,Comedy,Romance,Supernatural',
#        'Action,Fantasy,Mystery,Sci-Fi',
#        'Action,Award Winning,Drama,Suspense', 'Comedy,Fantasy,Mystery',
#        'Comedy,Mystery,Romance,Supernatural', 'Drama,Ecchi',
#        'Comedy,Erotica', 'Slice of Life,Hentai',
#        'Award Winning,Comedy,Drama,Fantasy,Slice of Life',
#        'Action,Fantasy,Supernatural,Ecchi', 'Romance,Sports,Ecchi',
#        'Avant Garde,Horror,Supernatural', 'Action,Girls Love',
#        'Comedy,Fantasy,Gourmet', 'Fantasy,Sci-Fi,Supernatural',
#        'Comedy,Girls Love,Romance,Slice of Life',
#        'Action,Comedy,Suspense', 'Fantasy,Mystery',
#        'Action,Adventure,Drama,Supernatural',
#        'Action,Comedy,Sci-Fi,Supernatural',
#        'Adventure,Comedy,Mystery,Supernatural',
#        'Comedy,Sci-Fi,Supernatural',
#        'Award Winning,Romance,Slice of Life',
#        'Avant Garde,Award Winning,Drama,Horror',
#        'Award Winning,Drama,Sports', 'Action,Fantasy,Horror',
#        'Action,Drama,Horror,Sci-Fi',
#        'Action,Adventure,Comedy,Fantasy,Slice of Life',
#        'Action,Fantasy,Romance,Ecchi', 'Boys Love,Comedy,Fantasy',
#        'Avant Garde,Comedy,Fantasy,Horror',
#        'Award Winning,Comedy,Supernatural',
#        'Horror,Mystery,Slice of Life,Suspense',
#        'Action,Romance,Supernatural,Ecchi', 'Boys Love,Drama,Sci-Fi',
#        'Gourmet,Romance,Slice of Life', 'Drama,Fantasy,Girls Love',
#        'Action,Adventure,Ecchi', 'Award Winning,Drama,Mystery',
#        'Action,Avant Garde,Fantasy,Sci-Fi,Supernatural,Ecchi',
#        'Gourmet,Ecchi', 'Action,Adventure,Fantasy,Mystery',
#        'Action,Drama,Fantasy,Horror', 'Fantasy,Sports',
#        'Action,Comedy,Girls Love', 'Adventure,Avant Garde',
#        'Boys Love,Romance,Slice of Life',
#        'Action,Fantasy,Girls Love,Ecchi',
#        'Award Winning,Drama,Sci-Fi,Supernatural',
#        'Mystery,Romance,Slice of Life', 'Action,Adventure,Sci-Fi,Sports',
#        'Action,Drama,Fantasy,Mystery,Sci-Fi,Supernatural',
#        'Action,Comedy,Drama,Supernatural', 'Action,Romance,Sci-Fi,Ecchi',
#        'Adventure,Fantasy,Romance,Sci-Fi', 'Comedy,Romance,Sports,Ecchi',
#        'Comedy,Sci-Fi,Slice of Life,Sports',
#        'Boys Love,Comedy,Drama,Romance,Slice of Life',
#        'Action,Fantasy,Slice of Life', 'Adventure,Avant Garde,Fantasy',
#        'Comedy,Fantasy,Supernatural,Hentai', 'Sci-Fi,Suspense',
#        'Drama,Horror,Mystery', 'Award Winning,Sports',
#        'Action,Fantasy,Supernatural,Suspense',
#        'Action,Comedy,Drama,Fantasy,Slice of Life',
#        'Drama,Fantasy,Horror',
#        'Comedy,Romance,Sci-Fi,Slice of Life,Supernatural',
#        'Action,Fantasy,Mystery,Supernatural',
#        'Comedy,Supernatural,Suspense',
#        'Action,Boys Love,Comedy,Supernatural',
#        'Boys Love,Drama,Romance,Slice of Life',
#        'Avant Garde,Fantasy,Horror', 'Fantasy,Gourmet,Slice of Life',
#        'Horror,Suspense', 'Comedy,Drama,Fantasy,Slice of Life',
#        'Action,Horror,Mystery,Suspense', 'Slice of Life,Ecchi',
#        'Action,Fantasy,Gourmet,Slice of Life', 'Fantasy,Gourmet',
#        'Adventure,Drama,Fantasy,Mystery,Sci-Fi',
#        'Adventure,Mystery,Sci-Fi',
#        'Adventure,Award Winning,Fantasy,Supernatural',
#        'Action,Avant Garde,Horror,Supernatural',
#        'Fantasy,Girls Love,Slice of Life', 'Comedy,Gourmet,Romance',
#        'Avant Garde,Supernatural',
#        'Boys Love,Comedy,Drama,Romance,Slice of Life,Supernatural,Erotica',
#        'Action,Fantasy,Mystery', 'Action,Award Winning,Drama,Mystery',
#        'Adventure,Mystery,Sci-Fi,Slice of Life',
#        'Adventure,Horror,Suspense', 'Drama,Horror,Mystery,Supernatural',
#        'Avant Garde,Sports', 'Drama,Horror,Supernatural',
#        'Adventure,Fantasy,Romance,Supernatural',
#        'Action,Adventure,Mystery,Romance',
#        'Action,Adventure,Fantasy,Mystery,Supernatural',
#        'Avant Garde,Ecchi', 'Drama,Fantasy,Gourmet,Romance',
#        'Action,Adventure,Fantasy,Horror,Mystery,Suspense',
#        'Action,Suspense', 'Action,Adventure,Drama,Fantasy,Mystery',
#        'Action,Boys Love,Horror,Supernatural,Suspense',
#        'Drama,Girls Love,Horror', 'Adventure,Boys Love,Drama,Mystery',
#        'Comedy,Girls Love,Slice of Life,Supernatural',
#        'Comedy,Drama,Gourmet,Romance',
#        'Action,Adventure,Award Winning,Drama,Fantasy',
#        'Action,Horror,Supernatural,Suspense', 'Action,Mystery,Romance',
#        'Comedy,Horror,Supernatural,Suspense',
#        'Award Winning,Drama,Mystery,Supernatural',
#        'Action,Adventure,Comedy,Fantasy,Mystery',
#        'Action,Award Winning,Fantasy', 'Boys Love,Comedy,Slice of Life',
#        'Boys Love,Comedy,Drama,Sci-Fi,Slice of Life', 'Mystery,Romance',
#        'Fantasy,Romance,Ecchi', 'Action,Comedy,Drama,Mystery,Romance',
#        'Action,Comedy,Fantasy,Horror',
#        'Adventure,Drama,Mystery,Romance,Sci-Fi',
#        'Action,Comedy,Drama,Mystery',
#        'Award Winning,Drama,Fantasy,Romance', 'Avant Garde,Comedy,Ecchi',
#        'Action,Mystery,Supernatural,Ecchi', 'Drama,Fantasy,Ecchi',
#        'Girls Love,Romance,Sci-Fi,Slice of Life',
#        'Action,Drama,Horror,Sci-Fi,Suspense',
#        'Drama,Romance,Slice of Life,Suspense,Hentai',
#        'Adventure,Award Winning,Comedy',
#        'Action,Adventure,Comedy,Sci-Fi,Suspense',
#        'Mystery,Romance,Sci-Fi', 'Action,Boys Love,Drama,Supernatural',
#        'Action,Fantasy,Gourmet,Ecchi',
#        'Boys Love,Drama,Girls Love,Romance,Slice of Life',
#        'Adventure,Drama,Fantasy,Erotica', 'Action,Fantasy,Romance,Sci-Fi',
#        'Adventure,Drama,Supernatural',
#        'Action,Comedy,Drama,Fantasy,Slice of Life,Ecchi',
#        'Award Winning,Comedy,Drama,Romance,Supernatural',
#        'Horror,Romance', 'Adventure,Fantasy,Girls Love,Mystery',
#        'Boys Love,Fantasy,Erotica',
#        'Action,Adventure,Comedy,Fantasy,Supernatural',
#        'Action,Adventure,Supernatural,Suspense', 'Fantasy,Mystery,Sci-Fi',
#        'Comedy,Fantasy,Suspense', 'Adventure,Sci-Fi,Suspense',
#        'Boys Love,Slice of Life',
#        'Boys Love,Drama,Horror,Mystery,Supernatural',
#        'Action,Adventure,Fantasy,Romance,Ecchi',
#        'Gourmet,Slice of Life,Sports',
#        'Action,Adventure,Comedy,Drama,Mystery', 'Action,Slice of Life',
#        'Comedy,Drama,Mystery,Romance',
#        'Action,Adventure,Fantasy,Girls Love', 'Boys Love,Romance,Hentai',
#        'Action,Drama,Fantasy,Mystery,Romance',
#        'Action,Adventure,Comedy,Mystery,Sports',
#        'Adventure,Mystery,Supernatural',
#        'Avant Garde,Horror,Mystery,Supernatural,Suspense',
#        'Comedy,Suspense', 'Comedy,Mystery,Romance,Suspense',
#        'Adventure,Comedy,Drama,Gourmet,Romance',
#        'Boys Love,Romance,Slice of Life,Erotica',
#        'Avant Garde,Slice of Life',
#        'Adventure,Award Winning,Fantasy,Suspense', 'Romance,Suspense',
#        'Adventure,Comedy,Mystery,Romance',
#        'Comedy,Romance,Sci-Fi,Supernatural'], dtype=object)

# %%
from collections import Counter
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

def simple_barplot(data, graph_name):
    # Process the genre column to split on comma and append resulting
    # genres all to a single list
    # all_genres = []
    # for item in anime_df["Genre"]:
    #     item = item.strip()
    #     all_genres.extend(item.split(','))


    # creating a dict from the data
    bar_date_dict = Counter(data)

    barplot_df=pd.DataFrame.from_dict(bar_date_dict,orient='index').reset_index() # creating a df from

    barplot_df=barplot_df.rename(columns={'index':graph_name, 0:'Count'}) # renaming the columns of the df

    bar_plot = sns.barplot(x=barplot_df[graph_name],y=barplot_df["Count"]) #assigning values to the plot

    bar_plot.bar_label(bar_plot.containers[0],label_type='edge', fontsize=6) # Show the values of each bar at their top

    plt.xticks(rotation=90) # rotate the name of the bars
    plt.show()

# %%
utils.simple_barplot(df_copy["Source"],"Source")

# %%
utils.simple_barplot(df_copy["Status"],"Status")

# %%
'''
Before the explode variable should be entered manually, now lets try creating it automatically depending on the data to analyze
'''
def pieplot(data, graph_name):
    # Create an axis object
    fig, ax = plt.subplots(1, 1, figsize = (15, 8))
    
    # Get the data in the right format
    piedata = Counter(data)

    height = list(piedata.keys())
    bars  = list(piedata.values())
    
    # Assign explode value automatically depending on the data and
    # declaring the exploding pie to separate one of the parts, in this case, the higher
    max_val = max(bars)
    max_index = bars.index(max_val)
    length =len(bars)
    explode_value = tuple([0 if i!=max_index else 0.2 for i in range(length)])

    # Plot the pie chart
    ax.pie(bars, labels = height, shadow = False, explode=explode_value ,startangle = 0, autopct = "%1.2f%%")

    #ax.axis('equal')
    ax.set_title(f"Pie chart for {graph_name} category.")
    
    # Save the plot to an image

    # Show graphic
    plt.show()

    # Close the plot
    plt.close()

# %%
utils.pieplot(df_copy["Type"],"Type")

# %%
print(df.value_counts(subset=['Released', 'Type']).sort_index())

# %%
#Creating df with just year and producers columns
columns = ['Released', 'Type']
df_re_pro = pd.DataFrame(df_copy, columns=columns)
df_re_pro.head()

# %%
# # Separating producers 
# df_re_pro_ex = df_re_pro.assign(Producers=df_re_pro['Type'].str.split(',')).explode('Type')
# df_re_pro_ex.head()

# %%
df_re_pro.groupby(["Released", "Type"]).count()

# %%
print(df_re_pro.value_counts(subset=['Released', 'Type']).sort_index()).reset_index(name='counts')

# %%
sns.countplot(x='Released',hue='Type',data=df_re_pro)
sns.set(rc={'figure.figsize':(30,30)})
plt.title("Releases por productora por año")
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.countplot(x='Released',hue='Producers',data=df_re_pro_ex,order=pd.value_counts(df_re_pro_ex['Released']).iloc[3:].index)
sns.set(rc={'figure.figsize':(30,30)})
plt.title("3 ños donde menos releases se hicieron")

# %%
#Calculate the correlation
df.corr()

# %%
#Producers by year
columns = ['Released', 'Producers']
df = pd.DataFrame(anime_df, columns=columns)
df_re_pro2 = df.assign(Producers=df['Producers'].str.split(',')).explode('Producers')
df_re_pro2

# %%
df_copy.fillna("",inplace=True)

# %%
df_copy_2 = df_copy.copy()

# %%
#Histogram of Score values without zero
new = df_copy_2['Score'].copy()
plt.hist(new[new>0], color="grey")

# %%
#Histogram of Score values without zero
new = df_copy_2['Score'].copy()
import seaborn as sns
# Plot the histogram thanks to the distplot function
sns.distplot( a=new[new>0], hist=True, kde=False, rug=False )

# %%
utils.complex_barplot(df_copy["Theme"],"Theme")

# %%
def split(df,categ):
    categ_list = []
    for item in df[categ]:
        item = item.strip().split(',')
        categ_list.extend(item)
    list_data = Counter(categ_list)
    return list_data

def barplot(df, categ):
    categ_list = []
    for item in df[categ]:
        item = item.strip().split(',')
        categ_list.extend(item)
    list_data = Counter(categ_list)

    height = list(list_data.keys()) 
    bars = list(list_data.values()) 

    x_pos = np.arange(len(height))

    # Create bars
    plt.bar(x_pos, bars)

    # Create names on the x-axis
    plt.xticks(x_pos, height, color='orange',rotation=90)
    plt.yticks(color='orange')


    # Show graphic
    plt.show()

# %%
barplot(df_copy,"Audience")

# %% [markdown]
# ## Rellenando valores nulos en Score

# %%
df_copy
# Out:
#           Type       Source  N_Episodes       Duration            Status  \
# 0           TV     Original          26  24 min per ep   Finished Airing
# 1        Movie     Original           1    1 hr 55 min   Finished Airing
# 2           TV        Manga          26  24 min per ep   Finished Airing
# 3           TV     Original          26  25 min per ep   Finished Airing
# 4           TV        Manga          52  23 min per ep   Finished Airing
# ...        ...          ...         ...            ...               ...
# 25616  Special        Manga           1          1 min   Finished Airing
# 25619    Music     Original           1          4 min   Finished Airing
# 25620      ONA  Light novel           0          2 min  Currently Airing
# 25807      ONA        Other           1          3 min   Finished Airing
# 25811  Special     Original           1         24 min   Finished Airing
#
#                                Rating  Score  Scored_by  Rank  \
# 0      R - 17+ (violence & profanity)   8.75     871603    38
# 1      R - 17+ (violence & profanity)   8.38     199009   182
# 2           PG-13 - Teens 13 or older   8.22     338974   320
# 3           PG-13 - Teens 13 or older   7.25      42103  2778
# 4                       PG - Children   6.94       6307  4219
# ...                               ...    ...        ...   ...
# 25616       PG-13 - Teens 13 or older   6.20        445  8136
# 25619       PG-13 - Teens 13 or older   6.59        221  5969
# 25620       PG-13 - Teens 13 or older   6.55        479  6203
# 25807                    G - All Ages   6.20        933  8134
# 25811       PG-13 - Teens 13 or older   6.14        168  8466
#
#                                       Genre                 Theme  Released  \
# 0                             Action,Sci-Fi      Adult Cast,Space      1998
# 1                             Action,Sci-Fi      Adult Cast,Space      2001
# 2      Action,Adventure,Comedy,Drama,Sci-Fi            Adult Cast      1998
# 3         Action,Drama,Mystery,Supernatural             Detective      2002
# 4            Adventure,Fantasy,Supernatural               Unknown      2004
# ...                                     ...                   ...       ...
# 25616    Comedy,Romance,Sci-Fi,Supernatural               Unknown      2022
# 25619                               Unknown                 Music      2022
# 25620                        Comedy,Fantasy  Isekai,Reincarnation      2022
# 25807               Action,Adventure,Sci-Fi        Military,Space      2022
# 25811                                Sci-Fi    Mecha,School,Space      2022
#
#                 Studios                                          Producers
# 0               Sunrise                                      Bandai Visual
# 1                 Bones                              Sunrise,Bandai Visual
# 2              Madhouse                               Victor Entertainment
# 3               Sunrise  TV Tokyo,Bandai Visual,Dentsu,Victor Entertain...
# 4        Toei Animation                                    TV Tokyo,Dentsu
# ...                 ...                                                ...
# 25616  David Production                                            Unknown
# 25619           Unknown                                            Unknown
# 25620    Studio PuYUKAI                 AT-X,BS NTV,Kadokawa,NewGin,Aiming
# 25807     Studio Ghibli                                            Unknown
# 25811           Sunrise                                            Unknown
#
# [14867 rows x 14 columns]

# %%
new_df_score = df_copy[['Type', 'Source',"Genre", 'Score', 'Rank']].copy()

# %%
new_df_score
# Out:
#           Type    Source                                              Genre  \
# 0           TV  Original                               ['Action', 'Sci-Fi']
# 1        Movie  Original                               ['Action', 'Sci-Fi']
# 2           TV     Manga  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 3           TV  Original     ['Action', 'Drama', 'Mystery', 'Supernatural']
# 4           TV     Manga           ['Adventure', 'Fantasy', 'Supernatural']
# ...        ...       ...                                                ...
# 25847    Music  Original                                                 []
# 25848  Special  Original                                         ['Comedy']
# 25849       TV  Original                 ['Action', 'Adventure', 'Fantasy']
# 25850       TV  Original  ['Action', 'Adventure', 'Drama', 'Mystery', 'S...
# 25851    Music     Novel                                        ['Romance']
#
#        Score    Rank
# 0       8.75    38.0
# 1       8.38   182.0
# 2       8.22   320.0
# 3       7.25  2778.0
# 4       6.94  4219.0
# ...      ...     ...
# 25847   0.00     0.0
# 25848   0.00     0.0
# 25849   0.00     0.0
# 25850   0.00     0.0
# 25851   0.00     0.0
#
# [25852 rows x 5 columns]

# %%
Genre = df_copy['Genre'].str.split(',').explode().value_counts()

# %%
new_df_score['Score'].value_counts()
# Out:
# 6.13    5752
# 6.02    2492
# 6.88     734
# 6.06     673
# 6.40     492
#         ...
# 3.46       1
# 3.16       1
# 3.67       1
# 1.85       1
# 8.83       1
# Name: Score, Length: 565, dtype: int64

# %%
new_df_score['Score'].value_counts()
new_df_score['Score'] = (np.where(new_df_score['Score']==0,new_df_score['Score'].replace(0,np.nan).
                groupby(new_df_score['Source']).transform('median'),new_df_score['Score']))

# %%
new_df_score
# Out:
#           Type    Source                                              Genre  \
# 0           TV  Original                               ['Action', 'Sci-Fi']
# 1        Movie  Original                               ['Action', 'Sci-Fi']
# 2           TV     Manga  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 3           TV  Original     ['Action', 'Drama', 'Mystery', 'Supernatural']
# 4           TV     Manga           ['Adventure', 'Fantasy', 'Supernatural']
# ...        ...       ...                                                ...
# 25847    Music  Original                                                 []
# 25848  Special  Original                                         ['Comedy']
# 25849       TV  Original                 ['Action', 'Adventure', 'Fantasy']
# 25850       TV  Original  ['Action', 'Adventure', 'Drama', 'Mystery', 'S...
# 25851    Music     Novel                                        ['Romance']
#
#        Score    Rank
# 0       8.75    38.0
# 1       8.38   182.0
# 2       8.22   320.0
# 3       7.25  2778.0
# 4       6.94  4219.0
# ...      ...     ...
# 25847   6.13     0.0
# 25848   6.13     0.0
# 25849   6.13     0.0
# 25850   6.13     0.0
# 25851   6.78     0.0
#
# [25852 rows x 5 columns]

# %%
# Lets check again the percenteage of null values
((new_df_score.isnull().sum() / len(new_df_score))*100).sort_values(ascending = False)
# Out:
# Score     0.607303
# Type      0.464181
# Source    0.000000
# Genre     0.000000
# Rank      0.000000
# dtype: float64

# %%
#Print number of null per column
new_df_score.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Christiandda\Documents\GitHub\EDA\src\EDA_Anime.ipynb Celda 95 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA/src/EDA_Anime.ipynb#Y216sZmlsZQ%3D%3D?line=0'>1</a> #Print number of null per column
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA/src/EDA_Anime.ipynb#Y216sZmlsZQ%3D%3D?line=1'>2</a> new_df_score.isnull("NaN").sum()
#
# TypeError: isnull() takes 1 positional argument but 2 were given

# %%
new_df_score
# Out:
#           Type    Source                                              Genre  \
# 0           TV  Original                               ['Action', 'Sci-Fi']
# 1        Movie  Original                               ['Action', 'Sci-Fi']
# 2           TV     Manga  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 3           TV  Original     ['Action', 'Drama', 'Mystery', 'Supernatural']
# 4           TV     Manga           ['Adventure', 'Fantasy', 'Supernatural']
# ...        ...       ...                                                ...
# 25847    Music  Original                                                 []
# 25848  Special  Original                                         ['Comedy']
# 25849       TV  Original                 ['Action', 'Adventure', 'Fantasy']
# 25850       TV  Original  ['Action', 'Adventure', 'Drama', 'Mystery', 'S...
# 25851    Music     Novel                                        ['Romance']
#
#        Score    Rank
# 0       8.75    38.0
# 1       8.38   182.0
# 2       8.22   320.0
# 3       7.25  2778.0
# 4       6.94  4219.0
# ...      ...     ...
# 25847   5.80     0.0
# 25848   6.20     0.0
# 25849   7.00     0.0
# 25850    NaN     0.0
# 25851   6.39     0.0
#
# [25852 rows x 5 columns]

# %%
fill_vals = new_df_score.Score.mask(new_df_score.Score.eq(0)).groupby(new_df_score['Type','Source','Genre']).transform(np.nanmedian)
new_df_score.assign(salary = new_df_score.Score.mask(new_df_score.Score.eq(0), fill_vals))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Christiandda\miniconda3\envs\ramup_py39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Christiandda\miniconda3\envs\ramup_py39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Christiandda\miniconda3\envs\ramup_py39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Type', 'Source', 'Genre')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Christiandda\Documents\GitHub\EDA\src\EDA_Anime.ipynb Celda 92 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA/src/EDA_Anime.ipynb#Y211sZmlsZQ%3D%3D?line=0'>1</a> fill_vals = new_df_score.Score.mask(new_df_score.Score.eq(0)).groupby(new_df_score['Type','Source','Genre']).transform(np.nanmedian)
#       <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA/src/EDA_Anime.ipynb#Y211sZmlsZQ%3D%3D?line=1'>2</a> new_df_score.assign(salary = new_df_score.Score.mask(new_df_score.Score.eq(0), fill_vals))
#
# File c:\Users\Christiandda\miniconda3\envs\ramup_py39\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\Christiandda\miniconda3\envs\ramup_py39\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: ('Type', 'Source', 'Genre')

# %%
new_df_score["Score"] = new_df_score.groupby(['Type','Source','Genre']).transform(lambda x: x.fillna(x.mean()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Christiandda\Documents\GitHub\EDA\src\EDA_Anime.ipynb Celda 92 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA/src/EDA_Anime.ipynb#Y204sZmlsZQ%3D%3D?line=0'>1</a> new_df_score["Score"] = new_df_score.groupby(['Type','Source','Genre']).transform(lambda x: x.fillna(x.mean()))
#
# File c:\Users\Christiandda\miniconda3\envs\ramup_py39\lib\site-packages\pandas\core\frame.py:3645, in DataFrame.__setitem__(self, key, value)
#    3643     self._setitem_array(key, value)
#    3644 elif isinstance(value, DataFrame):
# -> 3645     self._set_item_frame_value(key, value)
#    3646 elif (
#    3647     is_list_like(value)
#    3648     and not self.columns.is_unique
#    3649     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3650 ):
#    3651     # Column to set is duplicated
#    3652     self._setitem_array([key], value)
#
# File c:\Users\Christiandda\miniconda3\envs\ramup_py39\lib\site-packages\pandas\core\frame.py:3775, in DataFrame._set_item_frame_value(self, key, value)
#    3773 len_cols = 1 if is_scalar(cols) else len(cols)
#    3774 if len_cols != len(value.columns):
# -> 3775     raise ValueError("Columns must be same length as key")
#    3777 # align right-hand-side columns if self.columns
#    3778 # is multi-index and self[key] is a sub-frame
#    3779 if isinstance(self.columns, MultiIndex) and isinstance(
#    3780     loc, (slice, Series, np.ndarray, Index)
#    3781 ):
#
# ValueError: Columns must be same length as key

# %%
new_df_score['Score'] = new_df_score.groupby(['Type','Source'])['Score']\
.transform(lambda x: x.replace(x.mean()))

# %%
new_df_score
# Out:
#           Type    Source                                              Genre  \
# 0           TV  Original                               ['Action', 'Sci-Fi']
# 1        Movie  Original                               ['Action', 'Sci-Fi']
# 2           TV     Manga  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 3           TV  Original     ['Action', 'Drama', 'Mystery', 'Supernatural']
# 4           TV     Manga           ['Adventure', 'Fantasy', 'Supernatural']
# ...        ...       ...                                                ...
# 25847    Music  Original                                                 []
# 25848  Special  Original                                         ['Comedy']
# 25849       TV  Original                 ['Action', 'Adventure', 'Fantasy']
# 25850       TV  Original  ['Action', 'Adventure', 'Drama', 'Mystery', 'S...
# 25851    Music     Novel                                        ['Romance']
#
#        Score    Rank
# 0       8.75    38.0
# 1       8.38   182.0
# 2       8.22   320.0
# 3       7.25  2778.0
# 4       6.94  4219.0
# ...      ...     ...
# 25847   0.00     0.0
# 25848   0.00     0.0
# 25849   0.00     0.0
# 25850   0.00     0.0
# 25851   0.00     0.0
#
# [25852 rows x 5 columns]

# %%
new_df_score['Score'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 25852 entries, 0 to 25851
# Series name: Score
# Non-Null Count  Dtype
# --------------  -----
# 13389 non-null  float64
# dtypes: float64(1)
# memory usage: 202.1 KB

# %%
utils.simple_barplot(new_df_score['Score'],"Source")

# %%
sd.apply(print)

# %%
data1 = new_df_score.groupby("Genre")

# %%
data1 = new_df_score.groupby('Genre')['Score'].mean().reset_index()

# %%
data1.columns = ['Category','Mean']

# %%
data1

# %%
data1 = new_df_score.groupby('Type', 'Source')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Christiandda\miniconda3\envs\ramup_py39\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'Source'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\Christiandda\Documents\GitHub\EDA\src\EDA_Anime.ipynb Celda 94 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Christiandda/Documents/GitHub/EDA/src/EDA_Anime.ipynb#Y166sZmlsZQ%3D%3D?line=0'>1</a> data1 = new_df_score.groupby('Type', 'Source')
#
# File c:\Users\Christiandda\miniconda3\envs\ramup_py39\lib\site-packages\pandas\core\frame.py:7713, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7711 if level is None and by is None:
#    7712     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
#    7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    (...)
#    7728     dropna=dropna,
#    7729 )
#
# File c:\Users\Christiandda\miniconda3\envs\ramup_py39\lib\site-packages\pandas\core\generic.py:552, in NDFrame._get_axis_number(cls, axis)
#     550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
# --> 552     raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named Source for object type DataFrame

# %%
data1 = data.groupby('Category')['Value'].mean().reset_index()
data1.columns = ['Category','Mean']
data = data.join(data1.set_index('Category'), on='Category')
data['Value'] = data['Value'].fillna(data['Mean'])
data=data.drop('Mean',axis=1)
data

# %%
#The purpose of this EDA is to analyze scored animes, for this reason So will eliminate the rows that have a score as "0".
# score_eliminated = df_copy[df_copy['Score'] == 0].index
# 
# df_copy.drop(score_eliminated , inplace = True)

# %%
df_prueba = df_copy[(df_copy["Type"]== "Music") & (df_copy["Rating"] == "G - All Ages")]
df_prueba

# %%
df_copy

# %%
df_copy_copy['Duration'] = df_copy['Duration'].str.replace(" hr", '*60').str.replace(' min','*1').str.replace(' sec','*0.01').str.replace(' ','+').str.replace('per','').str.replace('ep','').str.replace('Unknown','0').apply(eval)

# %%
count = df_copy['Released'].value_counts()[0]

# %%
column = df_copy['Rank']
count = column[column == 0].count()
count
# Out:
# 4346

# %% [markdown]
# ##  pruebas no paramétricas

# %%
df_season = df.dropna(subset="Season")
df_type = df.dropna(subset="Type")
df_rating = df.dropna(subset="Rating")
df_score = df.dropna(subset="Score")

# %%
df_season["Season"].unique()
# Out:
# array(['spring', 'summer', 'fall', 'winter'], dtype=object)

# %%
df.Status.value_counts(normalize = True)
# Out:
# Finished Airing     0.950139
# Not yet aired       0.032918
# Currently Airing    0.016943
# Name: Status, dtype: float64

# %%
var_status_season = pd.crosstab(df_season["Status"],df_season["Season"]) # para ver si hay dependencia
var_status_season
# Out:
# Season            fall  spring  summer  winter
# Status
# Currently Airing    67      26       8      11
# Finished Airing   1488    1698     930    1036
# Not yet aired        1      22       4      51

# %%
from scipy.stats import chi2_contingency #prueba no paramétrica (primer valor es el chi estadístico, lo que se espera para aceptarlo. segundo el p-value.(al ser más pequeñó de 0.05))
chi2_contingency(var_status_season)
# Out:
# (158.22510050716494,
#  1.4070021357089775e-31,
#  6,
#  array([[  32.62298765,   36.60651441,   19.7499064 ,   23.02059154],
#         [1500.65743167, 1683.89966305,  908.4956945 , 1058.94721078],
#         [  22.71958068,   25.49382254,   13.7543991 ,   16.03219768]]))

# %%
var_rate_season = pd.crosstab(df_season["Rating"],df_season["Season"]) # para ver si hay dependencia
var_rate_season
# Out:
# Season                          fall  spring  summer  winter
# Rating
# G - All Ages                     341     390     136     245
# PG - Children                    199     276     128     139
# PG-13 - Teens 13 or older        734     828     485     533
# R - 17+ (violence & profanity)   179     138     111      98
# R+ - Mild Nudity                  74      75      66      46

# %% [markdown]
# vemos que ningun pais es favorecido por eurovision

# %%
from scipy.stats import chi2_contingency #prueba no paramétrica (primer valor es el chi estadístico, lo que se espera para aceptarlo. segundo el p-value.(al ser más pequeñó de 0.05))
chi2_contingency(var_rate_season)
# Out:
# (58.618326175249585,
#  4.026380394304237e-08,
#  12,
#  array([[325.22964949, 363.56713273, 197.22505267, 225.9781651 ],
#         [217.01474813, 242.5960544 , 131.60160889, 150.78758858],
#         [754.57958246, 843.52805976, 457.5904999 , 524.30185788],
#         [153.84064355, 171.97510056,  93.29170657, 106.89254932],
#         [ 76.33537636,  85.33365256,  46.29113197,  53.03983911]]))

# %%
var_season = pd.crosstab(df_season["Season"],df_season["Season"])
var_season
# Out:
# Season  fall  spring  summer  winter
# Season
# fall    1556       0       0       0
# spring     0    1746       0       0
# summer     0       0     942       0
# winter     0       0       0    1098

# %%
df.Season.value_counts(normalize = True)
# Out:
# spring    0.326844
# fall      0.291277
# winter    0.205541
# summer    0.176338
# Name: Season, dtype: float64

# %%
from scipy.stats import chi2_contingency #prueba no paramétrica (primer valor es el chi estadístico, lo que se espera para aceptarlo. segundo el p-value.(al ser más pequeñó de 0.05))
chi2_contingency(var_season)
# Out:
# (16026.0,
#  0.0,
#  9,
#  array([[453.22650693, 508.56907525, 274.38262823, 319.82178959],
#         [508.56907525, 570.66941221, 307.88693373, 358.87457881],
#         [274.38262823, 307.88693373, 166.11081992, 193.61961812],
#         [319.82178959, 358.87457881, 193.61961812, 225.68401348]]))

# %%
var_score_season = pd.crosstab(df_season["Score"],df_season["Season"])
var_score_season
# Out:
# Season  fall  spring  summer  winter
# Score
# 2.91       0       0       0       1
# 3.13       0       1       0       0
# 3.29       0       1       0       0
# 3.30       0       0       0       1
# 3.33       0       0       1       0
# ...      ...     ...     ...     ...
# 9.07       0       1       0       0
# 9.08       0       1       0       0
# 9.09       0       1       0       0
# 9.10       1       0       0       0
# 9.12       0       1       0       0
#
# [430 rows x 4 columns]

# %%
chi2_contingency(var_score_season) #prueba no paramétrica (primer valor es el chi estadístico, lo que se espera para aceptarlo. segundo el p-value.)
# Out:
# (1329.7806006084943,
#  0.19845239623044283,
#  1287,
#  array([[0.29993009, 0.32090422, 0.17711489, 0.2020508 ],
#         [0.29993009, 0.32090422, 0.17711489, 0.2020508 ],
#         [0.29993009, 0.32090422, 0.17711489, 0.2020508 ],
#         ...,
#         [0.29993009, 0.32090422, 0.17711489, 0.2020508 ],
#         [0.29993009, 0.32090422, 0.17711489, 0.2020508 ],
#         [0.29993009, 0.32090422, 0.17711489, 0.2020508 ]]))

# %%
df_season = df.dropna(subset="Season")
for i in df.columns:
    if i != "Season":
        var_season = pd.crosstab(df_season[i],df_season["Season"])
        x,p,z,h = chi2_contingency(var_season)
        if p> 0.05:
            print(i)
# Out:
# Cover
# English_Title
# Japanses_Title
# Type
# Score
# Scored_by
# Rank

# %%
 #prueba no paramétrica (primer valor es el chi estadístico, lo que se espera para aceptarlo. segundo el p-value.)
chi2_contingency(var_season)
# Out:
# (8084.379173542643,
#  0.0031358501825626667,
#  7740,
#  array([[2.91276675e-01, 3.26843879e-01, 1.76338450e-01, 2.05540996e-01],
#         [2.91276675e-01, 3.26843879e-01, 1.76338450e-01, 2.05540996e-01],
#         [2.91276675e-01, 3.26843879e-01, 1.76338450e-01, 2.05540996e-01],
#         ...,
#         [1.74766005e+00, 1.96106327e+00, 1.05803070e+00, 1.23324598e+00],
#         [2.91276675e-01, 3.26843879e-01, 1.76338450e-01, 2.05540996e-01],
#         [3.93806065e+02, 4.41892924e+02, 2.38409584e+02, 2.77891426e+02]]))

# %%
df.Cover.value_counts(normalize = True)
# Out:
# https://cdn.myanimelist.net/img/sp/icon/apple-touch-icon-256.png    0.054309
# https://cdn.myanimelist.net/images/anime/1096/120335l.jpg           0.000116
# https://cdn.myanimelist.net/images/anime/4/19644l.jpg               0.000039
# https://cdn.myanimelist.net/images/anime/1398/105660l.jpg           0.000039
# https://cdn.myanimelist.net/images/anime/1778/105047l.jpg           0.000039
#                                                                       ...
# https://cdn.myanimelist.net/images/anime/3/54119l.jpg               0.000039
# https://cdn.myanimelist.net/images/anime/1992/96603l.jpg            0.000039
# https://cdn.myanimelist.net/images/anime/5/52981l.jpg               0.000039
# https://cdn.myanimelist.net/images/anime/7/52985l.jpg               0.000039
# https://cdn.myanimelist.net/images/anime/1740/131344l.jpg           0.000039
# Name: Cover, Length: 24447, dtype: float64

# %%
df.Cover.nunique() == len(df)

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

df = with_zeros

x1 = df.loc[:,['Score','Scored_by']]
y1 = df.loc[:,['Rank']]

print ("Statsmodel.Formula.Api Method")
model1 = smf.ols(formula='Rank ~ Score + Scored_by', data=df).fit()
print (model1.params)

print ("\nStatsmodel.Api Method")
model2 = sm.OLS(y1, x1)
results = model2.fit()
print (results.params)

print ("\nSci-Kit Learn Method")
model3 = LinearRegression()
model3.fit(x1, y1)
print (model3.coef_)
print (model3.intercept_)

# %%
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Rank   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                     3327.
# Date:                Tue, 29 Nov 2022   Prob (F-statistic):               0.00
# Time:                        13:14:57   Log-Likelihood:            -2.6229e+05
# No. Observations:               25852   AIC:                         5.246e+05
# Df Residuals:                   25849   BIC:                         5.246e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.549e+04    359.219     98.791      0.000    3.48e+04    3.62e+04
# Score      -4194.1911     56.923    -73.682      0.000   -4305.763   -4082.619
# Scored_by     -0.0029      0.000     -6.122      0.000      -0.004      -0.002
# ==============================================================================
# Omnibus:                      525.967   Durbin-Watson:                   1.253
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.590
# Skew:                           0.102   Prob(JB):                     9.79e-68
# Kurtosis:                       2.505   Cond. No.                     8.49e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
lista_new = []
for element in df_copy['Producers']:
    ele = element.split(',')
    for element in ele:
        lista_new.append(element)

# %%
lista = set(lista_new)

list_producer = []
for producer in lista:
    dict_producer = {'Score': df_copy.loc[df_copy['Producers'].str.contains(producer)]['Score'].mean(),
                    'Producer': producer,
                    'Scored_by': df_copy.loc[df_copy['Producers'].str.contains(producer)]['Scored_by'].mean()
                    }
    list_producer.append(dict_producer)

df_prueba = pd.DataFrame(list_producer)

# %%
#### OLD ONES


def split(df,categ):
    categ_list = []
    for item in df[categ]:
        item = item.strip().split(',')
        categ_list.extend(item)
    list_data = Counter(categ_list)
    return list_data

def barplot(df, xcolname, ycolname, cmap = 'YlGnBu', quantity = "occurrences"):

    y_pos = np.arange(len(ycolname))

    # Create bars
    plt.bar(y_pos, ycolname)

    # Create names on the x-axis
    plt.xticks(y_pos, xcolname)

    # Show graphic
    plt.show()

# %% [markdown]
# # Rating

# %% [markdown]
# - si tengo más de 0.05 en p-value no puedo decir que hay alguno más favorecido
# - si tengo menos de 0.05 en p-value puedo decir que hay alguno más favorecido

# %%
X2, p_value, degree_freedom, expected_values = stats.chi2_contingency(cont_table, correction = True)
print("X2: {0}, P-Value: {1}".format(X2,p_value))

# %%
X2, p_value, degree_freedom, expected_values = stats.chi2_contingency(cont_table, correction = True)
print("X2: {0}, P-Value: {1}".format(X2,p_value))
# Out:
# X2: 60654.02799506924, P-Value: 3.0173113278083997e-20

# %% [markdown]
# Planteamos la hipótesis:
# Mi hipótesis es que

# %%
df_copy.head(10)

# %%
df_rating = df_copy[["Rating","Score","Scored_by"]]

# %%
model = ols('Scored_by ~ Score',                 #  formula
            data = df_copy).fit()
                
anova_result = sm.stats.anova_lm(model, typ=2)
print (anova_result)
# Out:
#                 sum_sq       df           F         PR(>F)
# Score     2.753226e+13      1.0  490.790454  1.139522e-107
# Residual  1.352125e+15  24103.0         NaN            NaN

# %%
until_2022 = df_copy[df_copy["Released"] < 2023]
utils.top_10_multi(until_2022,'Rating','Score',"Scored_by")
# Out:
#                            Rating     Score  Scored_by
# 3  R - 17+ (violence & profanity)  6.880000  121762203
# 2       PG-13 - Teens 13 or older  6.623086  308203529
# 1                   PG - Children  6.577784  365061792
# 6                         Unknown  6.548898    3328605
# 4                R+ - Mild Nudity  6.360000   31130863
# 0                    G - All Ages  6.316820  151568672
# 5                     Rx - Hentai  6.170000    4337079

# %%
# score con media. Scored_b y con media
df_rating = utils.top_10_multi(df_copy,'Rating','Score',"Scored_by") 
df_rating
# Out:
#                            Rating     Score     Scored_by
# 3  R - 17+ (violence & profanity)  6.882970  88802.781977
# 2       PG-13 - Teens 13 or older  6.683179  37739.061279
# 1                   PG - Children  6.495474  91519.103785
# 6                         Unknown  6.463277   4773.122785
# 4                R+ - Mild Nudity  6.265436  29014.529357
# 0                    G - All Ages  6.185382  20956.564315
# 5                     Rx - Hentai  6.098950   3292.389691

# %%
df_rating["calculo"] = df_rating["Score"] * df_rating["Scored_by"]

# %%
df_rating["Score100"] = df_rating["Score"] * 10000

# %%
X = np.arange(len(df_rating['Score']))
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, df_rating['Score100'], color = 'b', width = 0.25)
ax.bar(X + 0.25, df_rating['Scored_by'], color = 'r', width = 0.25)
ax.bar(X + 0.50, df_rating['calculo'], color = 'g', width = 0.25)
plt.xticks([0, 1, 2, 3, 4, 5,6], df_rating['Rating'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.show()

# %%
height = df_rating["Score"]
bars = df_rating["Rating"]
y_pos = np.arange(len(bars))
# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xticks(rotation=90)
# Show graphic
plt.show()

# %%
df_rating
# Out:
#                            Rating     Score     Scored_by        calculo  \
# 3  R - 17+ (violence & profanity)  6.882970  88802.781977  611226.857879
# 2       PG-13 - Teens 13 or older  6.683179  37739.061279  252216.906989
# 1                   PG - Children  6.495474  91519.103785  594459.939757
# 6                         Unknown  6.463277   4773.122785   30850.016571
# 4                R+ - Mild Nudity  6.265436  29014.529357  181788.666746
# 0                    G - All Ages  6.185382  20956.564315  129624.356459
# 5                     Rx - Hentai  6.098950   3292.389691   20080.118997
#
#        Score100
# 3  68829.697029
# 2  66831.791369
# 1  64954.737882
# 6  64632.773892
# 4  62654.356550
# 0  61853.820363
# 5  60989.496637

# %%
# score con mediana. Scored_b y con mediana
utils.top_10_multi(df_copy,'Rating','Score',"Scored_by")
# Out:
#                            Rating     Score  Scored_by
# 3  R - 17+ (violence & profanity)  6.865000    14133.5
# 2       PG-13 - Teens 13 or older  6.623080     3691.5
# 6                         Unknown  6.599874      710.0
# 1                   PG - Children  6.577830     2169.0
# 4                R+ - Mild Nudity  6.360000     4839.0
# 0                    G - All Ages  6.316877      477.0
# 5                     Rx - Hentai  6.170000     1815.0

# %%
#score con mediana. Scored_by con suma
utils.top_10_multi(df_copy,'Rating','Score',"Scored_by")
# Out:
#                            Rating     Score  Scored_by
# 3  R - 17+ (violence & profanity)  6.865000  122192628
# 2       PG-13 - Teens 13 or older  6.623080  309158390
# 6                         Unknown  6.599874    3770767
# 1                   PG - Children  6.577830  365069705
# 4                R+ - Mild Nudity  6.360000   31132590
# 0                    G - All Ages  6.316877  151515960
# 5                     Rx - Hentai  6.170000    4790427

# %% [markdown]
# #### Scored_by

# %%
df_copy.sort_values(by = 'Scored_by', ascending = False).head(10)
# Out:
#                           English_Title Type    Source  N_Episodes  Duration  \
# 20478                   Wu Liao Kuaihuo  ONA  Original          12       5.0
# 20479                            Dai Li  ONA  Original          40       3.0
# 20477                 Wenzhou Naxie Shi   TV   Unknown          12       6.0
# 20480                 Jian Er Moshu Shi   TV  Original          48       7.0
# 20476                        Muma Yijia  ONA  Original          13       3.0
# 20481           Amy & Gollum 3rd Season  ONA   Unknown          52       5.0
# 20475  Xiaolong Wan Di: Huanle Xiaoyuan   TV  Original          26      12.0
# 20482                     Huahua Shizhe   TV  Original         390      13.0
# 20474      Dongbei Meng Shou 2nd Season  ONA  Original          12       4.0
# 20483             Duo Bao Chengzhang Ji  ONA  Original          36       5.0
#
#               Rating     Score  Scored_by   Rank    Genre            Theme  \
# 20478   G - All Ages  6.613038    4128912  17227   Comedy          Unknown
# 20479  PG - Children  6.613056    4127786  19355  Unknown          Unknown
# 20477  PG - Children  6.613019    4125905  17151  Fantasy          Unknown
# 20480  PG - Children  6.613075    4122420  20859  Unknown          Unknown
# 20476  PG - Children  6.613001    4118873  14399  Unknown  Anthropomorphic
# 20481  PG - Children  6.613093    4112705  18384  Fantasy  Anthropomorphic
# 20475  PG - Children  6.612982    4107924  17522  Fantasy  Anthropomorphic
# 20482  PG - Children  6.613111    4098535  20589  Unknown  Anthropomorphic
# 20474  PG - Children  6.612964    4093166  19531  Unknown  Anthropomorphic
# 20483  PG - Children  6.613130    4079801  19659  Unknown          Unknown
#
#        Released  Studios Producers
# 20478      2018  Unknown   Unknown
# 20479      2018  Unknown   Unknown
# 20477      2019  Unknown   Unknown
# 20480      2009  Unknown   Unknown
# 20476      2019  Unknown   Unknown
# 20481      2011  Unknown   Unknown
# 20475      2019  Unknown   Unknown
# 20482      2013  Unknown   Unknown
# 20474      2018  Unknown   Unknown
# 20483      2015  Unknown   Unknown

# %%
df_copy.to_pickle("cleaned.csv")

# %%
#Library imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import sys
import seaborn as sns
from collections import Counter
from utils import utils
import scipy.stats as stats
from scipy.stats import chi2_contingency
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.formula.api import ols
#import missingno as msno

# %%
df_cleaned = pd.read_pickle("cleaned.csv")
df_copy = df_cleaned.copy()

# %%
df_copy.sample()
# Out:
#                       English_Title Type    Source  N_Episodes  Duration  \
# 19678  Kuaile Baobei: Bai Bian Zimu   TV  Original          26       8.0
#
#               Rating     Score  Scored_by   Rank    Genre    Theme  Released  \
# 19678  PG - Children  6.595185     -48738  13480  Unknown  Unknown      2022
#
#        Studios Producers
# 19678  Unknown   Unknown

# %%
suma_score= top_mean["Score"].iloc[0:].astype(float).sum()
suma_Scored_by= top_mean["Scored_by"].iloc[0:].astype(float).sum()
top_mean['Score_Relativos'] = top_mean["Score"] / suma_score
top_mean['ScoreBy_Relativos'] = top_mean["Scored_by"] / suma_Scored_by
top_mean['Incidencia_Score_ScoreBy'] = (top_mean['ScoreBy_Relativos'] - top_mean['Score_Relativos'] ) / top_mean['Score_Relativos']
top_mean.sort_values(by='Incidencia_Score_ScoreBy', ascending=False)

# %% [markdown]
# # References

# %% [markdown]
# - [MyAnimeList.net](https://myanimelist.net/)
# - [from Data to Viz](https://www.data-to-viz.com/#connectedscatter)
# - [Seaborn Documentation](https://seaborn.pydata.org/)
# - [Matplotlib Documentation](https://matplotlib.org/)
# - [Data Visualization con pandas y seaborn](https://medium.com/ironhack/data-visualization-con-pandas-y-seaborn-1044906af34f)
# - [The Python Graph Gallery](https://www.python-graph-gallery.com/)
# - [Stack Overflow](https://stackoverflow.com/)
# - [codificandobits](https://www.codificandobits.com/blog/analisis-exploratorio-de-datos/)
# - [Towards data science](https://towardsdatascience.com/beautifying-the-messy-plots-in-python-solving-common-issues-in-seaborn-7372e6479fb)
# - [pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.explode.html)
